# %% [markdown]
# ## Relational Diagram
#
# *   Please click here: https://drive.google.com/file/d/1vhwxF_E1BflRkVSjNsjo3Oib3U1GsRK-/view?usp=sharing

# %% [markdown]
# ## Sampled Client (ID: I8LN9Q)
#
# *   this client has 4 accounts (**I8LN9QE**: Margin Long in CAD / **I8LN9QF**: Margin Long in USD / **I8LN9QS**: Cash in CAD / **I8LN9QW**: Cash in CAD)
# *   We will use this sampled client to see the column details or data structures in SP100, SP200, SP399, and BV399 datasets.

# %% [markdown]
# **First, let's look at the general profile information for this client, the following 103 columns are extracted from cust_acct_detail.csv**

# %%
# Out:
# (376, 103)
# ...

# %% [markdown]
# # SP100 (RRWS ACCOUNT PROFILE)
#
# 1.   cust_sp100_address.csv
# 2.   cust_sp100_client.csv
# 3.   sp100_accounts.csv
# 4.   sp100_clients.csv
# 5.   sp100_client_pension.csv

# %% [markdown]
# ## cust_sp100_address.csv

# %%
# Out:
#       acct_rep account_id address_postal_code  file_date
# 50065     0RC2    I8LN9QE                 L4J 2019-03-29
# 50067     0RC2    I8LN9QF                 L4J 2019-03-29
# 50068     0RC2    I8LN9QS                 L4J 2019-03-29
# 50091     0RC2    I8LN9QW                 L4J 2019-03-29

# %% [markdown]
# ## sp100_clients.csv

# %%
# Out:
# * 232786 rows and 20 columns
# * 36991 clients
# * 366 advisors
# * trading dates range from 2018-08-13 to 2019-08-12         ---> 251 trading days
#         birth_date client_id client_rep  file_date gender income inv_obj_1 inv_obj_2 inv_obj_3 inv_obj_4 inv_obj_5  inv_obj_6 language_cd net_worth  occupation postal_cd resident_cd risk_tolerance  seq_id updcode
# 19596         1959    I8LN9Q       0RC2 2018-09-07      F   100K      G.99       NaN       NaN       NaN       NaN        NaN           E     200K+  BOOKKEEPER       L4J          13       M.60H.40   16886       C
# 76775         1959    I8LN9Q       0RC2 2018-12-20      F   100K      G.99       NaN       NaN       NaN       NaN        NaN           E     200K+  BOOKKEEPER       L4J          13       M.60H.40   25101       C
# ...

# %% [markdown]
# ## cust_sp100_client.csv (similar to file cust_kyc_details.csv)

# %%
# Out:
# * 7122270 rows and 28 columns
# * 33051 clients
# * 81894 accounts
# * 332 advisors
# * trading dates range from 2019-03-29 to 2019-08-12       ---> 95 trading days
#         acct_type acct_service_code acct_rep acct_currency acct_internal_cde4 acct_internal_cde5           ivt_obj_cde account_id        risk_tolerance retail_plan_pension_origin client_residence_region client_language client_intro_rep client_id client_risk_tolerance client_occupation_desc client_net_worth client_annual_gross_inc  client_birth_date client_inv_knowledge_lvl client_sex client_inv_objective_1 client_inv_objective_2 client_inv_objective_3 client_inv_objective_4 client_inv_objective_5 client_inv_objective_6  file_date
# ...

# %% [markdown]
# ## sp100_accounts.csv
#
# RAP codes: https://drive.google.com/open?id=19p8dqqbeBNjPGLSwO_4SeXLV-1HsvI8l
#
# Account_type mapping: https://drive.google.com/open?id=1Gd6wmVKD7--Wg8nLR1LM0qcl6MJqzjyB

# %%
# Out:
# * 626737 rows and 12 columns
# * 36983 client
# * 97200 accounts
# * 366 advisors
# * trading dates range from 2018-08-13 to 2019-08-12         ---> 252 trading days
#        account_id acct_funds_cd acct_rep  acct_serv_cd    acct_type client_id  clnt_seq_id  close_date  file_date planning_code  seq_id updcode
# 429806    I8LN9QE             C     0RC2  000000000000  Margin Long    I8LN9Q        68729         NaN 2019-03-15           NaN   68729       C
# 429807    I8LN9QF             U     0RC2  000000000000  Margin Long    I8LN9Q        68730         NaN 2019-03-15           NaN   68730       C
# 429808    I8LN9QS             C     0RC2  000000000000         Cash    I8LN9Q        68731         NaN 2019-03-15           NaN   68731       C
# 624037    I8LN9QW             C     0RC2  000000000000         Cash    I8LN9Q         5353         NaN 2019-08-06           NaN    5353       C

# %% [markdown]
# ## sp100_client_pension.csv

# %%
# Out:
# * 443279 rows and 5 columns
# * 60656 accounts
# * trading dates range from 2018-08-13 to 2019-08-12         ---> 252 trading days
#        account_id  acct_seq_id  file_date pension_origin  seq_id
# 282237    I8LN9QS        68731 2019-03-15            NaN   42848
# 441013    I8LN9QW         5353 2019-08-06            NaN    4998

# %% [markdown]
# # SP200 (TRANSACTION DETAIL - POSITIONS)
#
# 1.   cust_sp200_trade.csv
# 2.   cust_sp200_transactions.csv
# 3.   sp200_position_details.csv
# 4.  sp200_position_multi_fill.csv
# 5.  sp200_position_trade_grp.csv

# %% [markdown]
# ## cust_sp200_trade.csv

# %%
# Out:
# * 98666 rows and 29 columns
# * 297 advisors
# * 299 trading reps
# * 24018 accounts in dataset
# * trading dates range from 2019-03-29 to 2019-08-12         ---> 95 trading days
#       acct_service_code acct_rep account_id                     ti_short_desc  ti_alternate_id   ti_cusip  tran_trading_gross_amt  tran_trading_total_qty  tran_trading_net_amt  tran_trading_comm_amt  tran_trading_fx_rate tran_trading_sp_tax_sw tran_trading_cancel_sw tran_trading_sav_plan_sts  tran_trading_process_date  tran_trading_trade_date  tran_trading_sett_date tran_trading_source  tran_trading_ds_ti_type tran_trading_prem_disc_cd tran_trading_type tran_trading_market tran_trading_net_currency  tran_trading_sub_account  tran_trading_off_sub_act tran_trading_currency tran_trading_rep tran_trading_ti_symbol  file_date
# ...

# %% [markdown]
# ## cust_sp200_transactions

# %%
# Out:
# * 1596651 rows and 18 columns
# * 322 advisors
# * 59624 accounts
# * trading dates range from 2019-03-29 to 2019-08-12         ---> 95 trading days
#         acct_service_code acct_rep account_id  ti_alternate_id   ti_cusip                   ti_symbol  tran_gross_amt  tran_settlement_date  tran_trade_date  tran_qty  tran_amount_2             tran_user_description tran_currency  tran_process_date tran_entry_description tran_type tran_type_of_amount_2  file_date
# 307938       000000000000     0RC2    I8LN9QE  118224           136069101  CM                                -1176.00              20190429         20190429     840.0            0.0  CDN IMPERIAL BK COMMERCE                   CAD           20190429              DIV             DIV                       2019-04-29
# ...

# %% [markdown]
# ## sp200_position_details

# %%
# Out:
# * 4253696 rows and 19 columns
# * 67123 accounts
# * trading dates range from 2018-08-13 to 2019-08-12         ---> 254 trading days
#         account_id                description entry_type  file_date  is_exchange  is_reversal  is_trade  net_amount       price price_funds  process_date  quantity security_id  seq_id  trade_date  txn_bv_mv_ind  valid_amount  valid_quantity  value_date
# 62418      I8LN9QE                  APPLE INC        DIV 2018-08-16            0            0         0       65.13         NaN           C      20180816      80.0      033740    4974    20180816              0             1               0    20180816
# 89014      I8LN9QE       ROYAL BANK OF CANADA        DIV 2018-08-24            0            0         0      869.50         NaN           C      20180824     925.0      591131    6440    20180824              0             1               0    20180824
# ...

# %% [markdown]
# ## sp200_position_multi_fill.csv

# %%
# Out:
# * 259527 rows and 8 columns
# * 42963 accounts
# * trading dates range from 2018-08-13 to 2019-08-12         ---> 253 trading days
#        account_id  file_date  funds_of_price  pos_seq_id      price  quantity security_id  seq_id
# 37415     I8LN9QE 2018-10-10             NaN        4541   51.52704     -1350      070623     973
# 37416     I8LN9QE 2018-10-10             NaN        4542   12.10000      5900      14439H     974
# 87832     I8LN9QE 2019-01-02             NaN       19913  102.05000       840      118224     627
# 87833     I8LN9QE 2019-01-02             NaN       19914    6.95000      2100      14439H     628
# 142914    I8LN9QE 2019-03-11             NaN        6520    4.73000     -1000      66908B     849
# 143853    I8LN9QE 2019-03-12             NaN        9717    4.73000      1000      66908B     693
# 143854    I8LN9QE 2019-03-12             NaN        9718    4.73000     -1000      66908B     694
# ...

# %% [markdown]
# ## sp200_position_trade_grp.csv

# %%
# Out:
# * 254870 rows and 23 columns
# * 42963 accounts
# * trading dates range from 2018-08-13 to 2019-08-12         ---> 253 trading days
#        account_id  bc_fee_cd  buy_sell_ind  empl_discount_ind  exchange_rate  file_date funds_of_price inventory_cd market_cd  multifill_ind orig_trade_account_id  pos_seq_id  qssp_coverage_ind rep_code security_id  seq_id special_tax_cd submit_loc_cd funds_of_price.1 trade_basis  trade_cancelled  trade_code trade_num
# 36705     I8LN9QE        NaN             1                  0            NaN 2018-10-10              C          NaN         T              0                   NaN        4541                  0     0RC2      070623     957            NaN             T                C           P                0           0     16515
# ...

# %% [markdown]
# # SP399 (RRWS DAILY RECONCILIATION FILE)
#
# 1.   cust_sp399_evaluation.csv
# 2.   cust_sp399_positions.csv (file is too large to load with other datasets, will provide later)
# 3.   sp399_balance_grp.csv
# 4.   sp399_evaluation_grp.csv

# %% [markdown]
# ## cust_sp399_evaluation.csv

# %%
# Out:
# * 8891238 rows and 16 columns
# * 97014 accounts
# * 354 advisors
# * trading dates range from 2019-03-29 to 2019-08-12         ---> 95 trading days
#         acct_service_code acct_rep account_id  acct_summ_td_net_amt  acct_summ_sd_net_amt  acct_summ_mkt_value  acct_summ_loan_value  acct_summ_sfk_loan_value  acct_summ_rtm_value  acct_summ_rts_value  acct_summ_rtm_value_alt  acct_summ_loan_value_alt  acct_summ_rts_value_alt  acct_summ_sfk_loan_val_alt  acct_summ_mkt_value_alt  file_date
# 56262        000000000000     0RC2    I8LN9QE               -359.90               -359.90            357799.49             236556.44                       0.0           -236916.34                  0.0               -236916.34                 236556.44                      0.0                         0.0                357799.49 2019-03-29
# ...

# %% [markdown]
# ## sp399_balance_grp.csv

# %%
# Out:
# * 81295990 rows and 9 columns
# * 97208 accounts
# * trading dates range from 2018-08-13 to 2019-08-12         ---> 254 trading days
#          account_id   amount  file_date  quantity security_id  seq_id  txn_bv_mv_ind  valid_amount  valid_quantity
# 206070      I8LN9QE  1599.78 2018-08-13       NaN         NaN  206531              0             1               0
# 206071      I8LN9QE      NaN 2018-08-13      80.0      033740  206532              0             0               1
# 206072      I8LN9QE      NaN 2018-08-13    1350.0      070623  206533              0             0               1
# 206073      I8LN9QE      NaN 2018-08-13   16000.0      28843F  206534              0             0               1
# 206074      I8LN9QE      NaN 2018-08-13     925.0      591131  206535              0             0               1
# 206075      I8LN9QE      NaN 2018-08-13    1100.0      66908B  206536              0             0               1
# ...

# %% [markdown]
# ## sp399_evaluation_grp.csv

# %%
# Out:
# * 13505397 rows and 13 columns
# * 67933 accounts
# * trading dates range from 2018-08-13 to 2019-08-12         ---> 254 trading days
#          account_id  bal_seq_id  curr_vd_bal  file_date  seq_id  td_loan_val  td_mkt_val  td_req_mgn  td_req_sec  vd_loan_val  vd_mkt_val  vd_req_mgn  vd_req_sec
# 33464       I8LN9QE      206531      1599.78 2018-08-13   33434    199137.30   290652.86  -200737.08         NaN    199137.30   290652.86  -200737.08         NaN
# 79352       I8LN9QE      206726      1599.78 2018-08-14   33479    200541.89   292483.41  -202141.67         NaN    200541.89   292483.41  -202141.67         NaN
# 125325      I8LN9QE      206944      1599.78 2018-08-15   33553    199764.43   291515.76  -201364.21         NaN    199764.43   291515.76  -201364.21         NaN
# 171327      I8LN9QE      207136      1664.91 2018-08-16   33598    201295.43   293886.89  -202960.34         NaN    201295.43   293886.89  -202960.34         NaN
# ...

# %% [markdown]
# # BV399 (BOOK VALUE)
#
# 1.   bv399_security_book_val.csv
# 2.   bv399_account_book_val.csv

# %% [markdown]
# ## bv399_security_book_val.csv

# %%
# Out:
# * 11114098 rows and 10 columns
# * 61116 accounts
# * trading dates range from 2018-08-13 to 2019-08-12         ---> 254 trading days
#          account_id fgn_ctt_ind   fi_id  file_date    pos_bv  pos_cos_qty pos_sus_ind     pro_dte rsp_elg_ind  seq_id
# 1451538     I8LN9QE           Y  033740 2018-10-10  12719.36           80         NaN  2017-08-17           Y   18265
# 1451539     I8LN9QE           N  070623 2018-10-10      0.00            0         NaN  2018-10-10           Y   18266
# 1451540     I8LN9QE           N  14439H 2018-10-10  71515.00         5900         NaN  2018-10-10           Y   18267
# 1451541     I8LN9QE           N  28843F 2018-10-10   6305.00        16000         NaN  2017-01-17           Y   18268
# 1451542     I8LN9QE           N  591131 2018-10-10  69297.50          925         NaN  2017-08-24           Y   18269
# 1451543     I8LN9QE           N  66908B 2018-10-10   4290.00         1100         NaN  2018-06-21           Y   18270
# ...

# %% [markdown]
# ## bv399_account_book_val.csv

# %%
# Out:
# * 1810848 rows and 9 columns
# * 67604 accounts
# * trading dates range from 2018-08-13 to 2019-08-12         ---> 254 trading days
#         account_id  act_bv_amt  act_csh_amt  act_fgn_pct  act_fgn_pct.1  file_date plan_id rep_code  seq_id
# 243440     I8LN9QE   242811.77       455.91          NaN            NaN 2018-10-10     NaN     0RC2    3061
# 250798     I8LN9QE   242811.77       455.91          NaN            NaN 2018-10-12     NaN     0RC2    3429
# 653359     I8LN9QE   343273.13       350.27          NaN            NaN 2019-01-02     NaN     0RC2    9093
# 673166     I8LN9QE   343273.13       350.27          NaN            NaN 2019-01-04     NaN     0RC2    2517
# 949876     I8LN9QE   318442.56       312.26          NaN            NaN 2019-02-28     NaN     0RC2    3045
# 997895     I8LN9QE   319147.56      4917.26          NaN            NaN 2019-03-11     NaN     0RC2    2892
# ...
