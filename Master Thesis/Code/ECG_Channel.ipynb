# %%
from google.colab import drive
drive.mount('/content/drive')
#!ls "/content/drive/My Drive/DL/ECG"  # check files in dir
#!kill -9 -1                       # clear memory
#!cat /proc/meminfo                # check memoery used
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pyedflib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk

plt.style.use('seaborn-whitegrid')
pd.set_option("display.max_columns",101)
# %matplotlib inline

import os

import time
import pickle
import gc

import tensorflow as tf
from sklearn.model_selection import train_test_split

# !pip install -U tensorboardcolab
from tensorboardcolab import *
import shutil
# Out:
# Requirement already up-to-date: tensorboardcolab in /usr/local/lib/python3.6/dist-packages (0.0.22)

# %% [markdown]
# # Define Functions

# %%
## One-hot encoding
def one_hot(labels, n_class = 4):
    """ One-hot encoding """
    expansion = np.eye(n_class)
    y = expansion[:,labels-1].T
    return y

## Standardize
def standardize(X):
    """ Standardize by mean and std for each measurement channel"""
    return (X - np.mean(X, axis=0)[None,:,:]) / np.std(X, axis=0)[None,:,:]

## Get batches
def get_batches(X, y, batch_size = 100):
    """ Yield batches ffrom data """
    n_batches = len(X) // batch_size
    X, y = X[:n_batches*batch_size], y[:n_batches*batch_size]

    # Loop over batches and yield
    for b in range(0, len(X), batch_size):
        yield X[b:b+batch_size], y[b:b+batch_size]

## Compute precision / recall / F1-Score / Accuracy within each class
def accuracy_train(confusion_matrix):
    diagonal_sum = confusion_matrix.trace()
    sum_of_all_elements = confusion_matrix.sum()
    return diagonal_sum / sum_of_all_elements 

def precision(label, confusion_matrix):
    col = confusion_matrix[:, label]
    return confusion_matrix[label, label] / col.sum()
    
def recall(label, confusion_matrix):
    row = confusion_matrix[label, :]
    return confusion_matrix[label, label] / row.sum()
  
def f1_score(label, confusion_matrix):
    prec = precision(label, confusion_matrix)
    rec = recall(label, confusion_matrix)
    return 2*prec*rec/(prec+rec)
  
def precision_macro_average(confusion_matrix):
    rows, columns = confusion_matrix.shape
    sum_of_precisions = 0
    
    for label in range(rows):
        sum_of_precisions += precision(label, confusion_matrix)
    return sum_of_precisions / rows
  
def recall_macro_average(confusion_matrix):
    rows, columns = confusion_matrix.shape
    sum_of_recalls = 0
    
    for label in range(columns):
        sum_of_recalls += recall(label, confusion_matrix)
    return sum_of_recalls / columns

# %% [markdown]
# # Data Pre-processing

# %%
channel_name = 'ECG'
X = np.load('drive/My Drive/DL/'+ channel_name+'/ECGdata.npy')
Y = np.load('drive/My Drive/DL/'+ channel_name+'/ECGdata.npy')

print('X shape:', X.shape)
print('*'*50)
X_tr, X_test, Y_tr, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2018)
del X
del Y
gc.collect()

# Standardize
X_tr = standardize(X_tr); X_test = standardize(X_test)

print('X_tr shape:', X_tr.shape)
print('*'*50)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_tr, Y_tr, test_size=0.2, stratify=Y_tr, random_state=2018)

# One-hot encode
y_train = one_hot(Y_train, n_class=4) 
y_valid = one_hot(Y_valid, n_class=4)
y_test = one_hot(Y_test, n_class=4)

print("Training set size: ", len(X_train))
print("Training Number of instances: ", X_train.shape[0])
print("Training Length of sequence: ", X_train.shape[1])
print("Training Number of channels: ", X_train.shape[2])
print('*'*50)
print("X_valid set size: ", len(X_valid))
print("X_valid Number of instances: ", X_valid.shape[0])
print("X_valid Length of sequence: ", X_valid.shape[1])
print("X_valid Number of channels: ", X_valid.shape[2])
print('*'*50)
print("X_valid set size: ", len(X_test))
print("X_valid Number of instances: ", X_test.shape[0])
print("X_valid Length of sequence: ", X_test.shape[1])
print("X_valid Number of channels: ", X_test.shape[2])
# Out:
# X shape: (21393, 15360, 2)
# **************************************************
# X_tr shape: (17114, 15360, 2)
# **************************************************
# Training set size:  13691
# Training Number of instances:  13691
# Training Length of sequence:  15360
# Training Number of channels:  2
# **************************************************
# X_valid set size:  3423
# X_valid Number of instances:  3423
# X_valid Length of sequence:  15360
# X_valid Number of channels:  2
# **************************************************
# X_valid set size:  4279
# X_valid Number of instances:  4279
# X_valid Length of sequence:  15360
# X_valid Number of channels:  2

# %%
# clean out the directory
shutil.rmtree('./graph', ignore_errors=True)
os.mkdir('./graph')

# start the tunneling and print out a link:
tbc = TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# http://470bfe0a.ngrok.io

# %% [markdown]
# # Build Tensorflow Computing Graph

# %%
# Hyperparameters
batch_size = 256       
seq_len = 15360       
learning_rate = 0.0001
epochs = 50

n_classes = 4
n_channels = 2

# Placeholders
graph = tf.Graph()

# Construct placeholders
with graph.as_default():
    inputs_ = tf.placeholder(tf.float32, [None, seq_len, n_channels], name = 'inputs')
    labels_ = tf.placeholder(tf.float32, [None, n_classes], name = 'labels')
    keep_prob_ = tf.placeholder(tf.float32, name = 'keep')
    learning_rate_ = tf.placeholder(tf.float32, name = 'learning_rate')
    
# Now, build the covolutional layers:
with graph.as_default():
    conv1 = tf.layers.conv1d(inputs=inputs_, filters=46, kernel_size=4, strides=2, 
                             padding='valid', activation = tf.nn.relu)
    print(conv1.get_shape())
    
    max_pool_1 = tf.layers.max_pooling1d(inputs=conv1, pool_size=4, strides=2, padding='valid')
    print(max_pool_1.get_shape())
    
    conv2 = tf.layers.conv1d(inputs=max_pool_1, filters=92, kernel_size=4, strides=2, 
                             padding='valid', activation = tf.nn.relu)
    print(conv2.get_shape())
    
    max_pool_2 = tf.layers.max_pooling1d(inputs=conv2, pool_size=4, strides=2, padding='valid')
    print(max_pool_2.get_shape())
    
    conv3 = tf.layers.conv1d(inputs=max_pool_2, filters=184, kernel_size=10, strides=2, 
                             padding='valid', activation = tf.nn.relu)
    print(conv3.get_shape())
    
    max_pool_3 = tf.layers.max_pooling1d(inputs=conv3, pool_size=10, strides=5, padding='valid')
    print(max_pool_3.get_shape())
    
# Flatten and pass to the classifier
with graph.as_default():
    # Flatten and add dropout
    flat = tf.reshape(max_pool_3, (-1, 94*184))
    flat_dp = tf.nn.dropout(flat, keep_prob=keep_prob_)
    
    # Predictions
    logits = tf.layers.dense(flat_dp, n_classes)
    
    # metrics, save y_p values to compute recall, precision, f1-score
    y_p = tf.argmax(logits, 1)
    
    # Cost function and optimizer
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels_))
    optimizer = tf.train.AdamOptimizer(learning_rate_).minimize(cost)
    
    # Accuracy
    correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(labels_, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

    #with tf.name_scope('logit'):
    #    tf.summary.scalar('Logits', logits)

    
#summaries = tf.summary.merge_all()
#train_writer = tbc.get_writer()
# Out:
# WARNING:tensorflow:From <ipython-input-9-68ba841e6f51>:22: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv1d instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# (?, 7679, 46)
# WARNING:tensorflow:From <ipython-input-9-68ba841e6f51>:25: max_pooling1d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.max_pooling1d instead.
# (?, 3838, 46)
# (?, 1918, 92)
# (?, 958, 92)
# (?, 475, 184)
# (?, 94, 184)
# WARNING:tensorflow:From <ipython-input-9-68ba841e6f51>:46: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From <ipython-input-9-68ba841e6f51>:49: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From <ipython-input-9-68ba841e6f51>:55: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %% [markdown]
# # Train CNN Models

# %%
validation_acc = []
validation_loss = []

train_acc = []
train_loss = []

train_recall = []
train_precision = []
train_f1 = []

validation_recall = []
validation_precision = []
validation_f1 = []

train_confusion_matrix = np.zeros((4,4))

with graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    iteration = 1
    
    # Loop over epochs
    for e in range(epochs):
        
        # Loop over batches
        for x,y in get_batches(X_train, y_train, batch_size):
            
            # Feed dictionary
            feed = {inputs_ : x, labels_ : y, keep_prob_ : 0.5, learning_rate_ : learning_rate}
            
            # Loss
            #summaries, loss, _ , acc, y_pred = sess.run([summaries, cost, optimizer, accuracy, y_p], feed_dict = feed)
            loss, _ , acc, y_pred = sess.run([cost, optimizer, accuracy, y_p], feed_dict = feed)
            train_acc.append(acc)
            train_loss.append(loss)
            
            recall_t = sk.metrics.recall_score(np.argmax(y, 1), y_pred, average=None)
            train_recall.append(recall_t)
            
            precision_t = sk.metrics.precision_score(np.argmax(y, 1), y_pred, average=None)
            train_precision.append(precision_t)
            
            f1_t = sk.metrics.f1_score(np.argmax(y, 1), y_pred, average=None)
            train_f1.append(f1_t)
            
            # Print at each 20 iters
            if (iteration % 20 == 0):
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {:d}".format(iteration),
                      "-> Train loss: {:6f}".format(loss),
                      "| Train acc: {:.6f}".format(acc),
                      #"| Train Recall: {}".format(np.mean(train_recall, axis=0)),
                      #"| Train Precision: {}".format(np.mean(train_precision, axis=0)),
                      "| Train f1-score: {}".format(np.mean(train_f1, axis=0)))
                
                #train_writer.add_summary(summaries, iteration)
            
            # Compute validation loss at every 10 iterations
            if (iteration%10 == 0):                
                val_acc_ = []
                val_loss_ = []
                val_recall_ = []
                val_precision_ = []
                val_f1_ = []
                
                for x_v, y_v in get_batches(X_valid, y_valid, batch_size):
                    # Feed
                    feed = {inputs_ : x_v, labels_ : y_v, keep_prob_ : 1.0}  
                    
                    # Loss
                    loss_v, acc_v, y_pred_v = sess.run([cost, accuracy, y_p], feed_dict = feed)                    
                    val_acc_.append(acc_v)
                    val_loss_.append(loss_v)
                    
                    recall_v = sk.metrics.recall_score(np.argmax(y_v, 1), y_pred_v, average=None)
                    val_recall_.append(recall_v)
                
                    precision_v = sk.metrics.precision_score(np.argmax(y_v, 1), y_pred_v, average=None)
                    val_precision_.append(precision_v)
                    
                    f1_v = sk.metrics.f1_score(np.argmax(y_v, 1), y_pred_v, average=None)
                    val_f1_.append(f1_v)
                    
                # Print info
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {:d}".format(iteration),
                      "-> Validation loss: {:6f}".format(np.mean(val_loss_)),
                      "Validation acc: {:.6f}".format(np.mean(val_acc_)),
                      #"Validation Recall: {}".format(np.mean(val_recall_,axis=0)),
                      #"Validation Precision: {}".format(np.mean(val_precision_,axis=0)),
                      "Validation f1-score: {}".format(np.mean(val_f1_,axis=0)))
                
                # Store
                validation_acc.append(np.mean(val_acc_))
                validation_loss.append(np.mean(val_loss_))     
                validation_recall.append(np.mean(val_recall_, axis=0))
                validation_precision.append(np.mean(val_precision_, axis=0))
                
            # Iterate 
            iteration += 1

            if e == epochs-1:
                train_confusion_matrix = train_confusion_matrix + sk.metrics.confusion_matrix(np.argmax(y, 1), y_pred)
            
    print(train_confusion_matrix.astype(int))  
    
    for label in range(4):
        print(f' Level:{label}  Accuracy:{accuracy_train(train_confusion_matrix):.4f}   Precision:{precision(label, train_confusion_matrix):.4f} \
                Recall:{recall(label, train_confusion_matrix):.4f}   F1-Score:{f1_score(label, train_confusion_matrix):.4f}')

    saver.save(sess,'drive/My Drive/DL/'+ channel_name+'/ccsh.ckpt')
    sess.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Epoch: 0/50 Iteration: 10 -> Validation loss: 1.361057 Validation acc: 0.255409 Validation f1-score: [0.         0.05786922 0.40041536 0.00473373]
# Epoch: 0/50 Iteration: 20 -> Train loss: 1.327912 | Train acc: 0.320312 | Train f1-score: [0.15091243 0.28584695 0.34628555 0.21026687]
# Epoch: 0/50 Iteration: 20 -> Validation loss: 1.322669 Validation acc: 0.420072 Validation f1-score: [0.37209361 0.48653884 0.31448008 0.41541622]
# Epoch: 0/50 Iteration: 30 -> Validation loss: 1.284822 Validation acc: 0.433293 Validation f1-score: [0.20119642 0.52956106 0.47320057 0.39216001]
# Epoch: 0/50 Iteration: 40 -> Train loss: 1.276470 | Train acc: 0.441406 | Train f1-score: [0.2300464  0.37680057 0.37642929 0.26564401]
# Epoch: 0/50 Iteration: 40 -> Validation loss: 1.244475 Validation acc: 0.488882 Validation f1-score: [0.46529506 0.55790692 0.48929301 0.39400097]
# Epoch: 0/50 Iteration: 50 -> Validation loss: 1.197699 Validation acc: 0.541466 Validation f1-score: [0.4786812  0.59894904 0.53743431 0.5263316 ]
# Epoch: 1/50 Iteration: 60 -> Train loss: 1.167789 | Train acc: 0.488281 | Train f1-score: [0.31648494 0.44479664 0.40516697 0.30768929]
# Epoch: 1/50 Iteration: 60 -> Validation loss: 1.142438 Validation acc: 0.525240 Validation f1-score: [0.46820188 0.61129513 0.52509133 0.45143775]
# Epoch: 1/50 Iteration: 70 -> Validation loss: 1.075549 Validation acc: 0.574219 Validation f1-score: [0.5537194  0.62580484 0.54260438 0.55153906]
# Epoch: 1/50 Iteration: 80 -> Train loss: 1.091440 | Train acc: 0.574219 | Train f1-score: [0.3679709  0.49419563 0.43531745 0.34882146]
# Epoch: 1/50 Iteration: 80 -> Validation loss: 1.014132 Validation acc: 0.601863 Validation f1-score: [0.57782524 0.66017827 0.54222116 0.59915164]
# Epoch: 1/50 Iteration: 90 -> Validation loss: 0.942848 Validation acc: 0.649038 Validation f1-score: [0.63945511 0.69855561 0.63546113 0.59895946]
# Epoch: 1/50 Iteration: 100 -> Train loss: 0.914319 | Train acc: 0.660156 | Train f1-score: [0.41527335 0.52936988 0.47338246 0.38895945]
# Epoch: 1/50 Iteration: 100 -> Validation loss: 0.883855 Validation acc: 0.689002 Validation f1-score: [0.68711517 0.72833351 0.66332587 0.65588884]
# Epoch: 2/50 Iteration: 110 -> Validation loss: 0.823084 Validation acc: 0.691707 Validation f1-score: [0.68367384 0.74017768 0.67842526 0.64231388]
# Epoch: 2/50 Iteration: 120 -> Train loss: 0.812702 | Train acc: 0.660156 | Train f1-score: [0.46037828 0.56490209 0.5026693  0.42529487]
# Epoch: 2/50 Iteration: 120 -> Validation loss: 0.766741 Validation acc: 0.710337 Validation f1-score: [0.70959603 0.748959   0.69197052 0.66926694]
# Epoch: 2/50 Iteration: 130 -> Validation loss: 0.719557 Validation acc: 0.721154 Validation f1-score: [0.72985664 0.77278639 0.7263109  0.6249786 ]
# Epoch: 2/50 Iteration: 140 -> Train loss: 0.721446 | Train acc: 0.726562 | Train f1-score: [0.49840874 0.59315016 0.53001034 0.45486635]
# Epoch: 2/50 Iteration: 140 -> Validation loss: 0.666754 Validation acc: 0.767728 Validation f1-score: [0.77243513 0.79783079 0.76598152 0.72449652]
# Epoch: 2/50 Iteration: 150 -> Validation loss: 0.633359 Validation acc: 0.787861 Validation f1-score: [0.79140454 0.81835556 0.7926251  0.73217996]
# Epoch: 3/50 Iteration: 160 -> Train loss: 0.545352 | Train acc: 0.812500 | Train f1-score: [0.53484595 0.62050659 0.55870842 0.48883162]
# Epoch: 3/50 Iteration: 160 -> Validation loss: 0.612677 Validation acc: 0.781851 Validation f1-score: [0.79548331 0.82612282 0.78708142 0.68286824]
# Epoch: 3/50 Iteration: 170 -> Validation loss: 0.568636 Validation acc: 0.810998 Validation f1-score: [0.82620105 0.8336208  0.80533272 0.76382019]
# Epoch: 3/50 Iteration: 180 -> Train loss: 0.513074 | Train acc: 0.851562 | Train f1-score: [0.56696612 0.64415475 0.58532665 0.52005588]
# Epoch: 3/50 Iteration: 180 -> Validation loss: 0.532207 Validation acc: 0.827524 Validation f1-score: [0.85033537 0.83199434 0.82807202 0.78758505]
# Epoch: 3/50 Iteration: 190 -> Validation loss: 0.505293 Validation acc: 0.839844 Validation f1-score: [0.85911245 0.85471884 0.83863686 0.79178292]
# Epoch: 3/50 Iteration: 200 -> Train loss: 0.470454 | Train acc: 0.855469 | Train f1-score: [0.59503377 0.66491515 0.61007756 0.54612892]
# Epoch: 3/50 Iteration: 200 -> Validation loss: 0.484628 Validation acc: 0.848558 Validation f1-score: [0.87513982 0.85819171 0.84191317 0.80777103]
# Epoch: 3/50 Iteration: 210 -> Validation loss: 0.447806 Validation acc: 0.871394 Validation f1-score: [0.89866832 0.87275226 0.86422264 0.84370434]
# Epoch: 4/50 Iteration: 220 -> Train loss: 0.436328 | Train acc: 0.882812 | Train f1-score: [0.6220286  0.68387149 0.63351525 0.5726017 ]
# Epoch: 4/50 Iteration: 220 -> Validation loss: 0.417881 Validation acc: 0.884315 Validation f1-score: [0.90950755 0.88144104 0.8813531  0.86176434]
# Epoch: 4/50 Iteration: 230 -> Validation loss: 0.396475 Validation acc: 0.888221 Validation f1-score: [0.91199851 0.88335991 0.88594379 0.86948313]
# Epoch: 4/50 Iteration: 240 -> Train loss: 0.373394 | Train acc: 0.875000 | Train f1-score: [0.64578587 0.70055639 0.65299305 0.5962378 ]
# Epoch: 4/50 Iteration: 240 -> Validation loss: 0.373541 Validation acc: 0.895433 Validation f1-score: [0.92235171 0.89086538 0.893143   0.87317669]
# Epoch: 4/50 Iteration: 250 -> Validation loss: 0.362368 Validation acc: 0.895433 Validation f1-score: [0.92171043 0.89258308 0.89121166 0.87217269]
# Epoch: 4/50 Iteration: 260 -> Train loss: 0.384379 | Train acc: 0.898438 | Train f1-score: [0.666443   0.71578117 0.67158535 0.61662836]
# Epoch: 4/50 Iteration: 260 -> Validation loss: 0.346039 Validation acc: 0.902945 Validation f1-score: [0.92981523 0.89830406 0.89050687 0.88979648]
# Epoch: 5/50 Iteration: 270 -> Validation loss: 0.325743 Validation acc: 0.912260 Validation f1-score: [0.93327301 0.9071241  0.90769202 0.90021711]
# Epoch: 5/50 Iteration: 280 -> Train loss: 0.321719 | Train acc: 0.914062 | Train f1-score: [0.68630927 0.72924828 0.6879304  0.63680029]
# Epoch: 5/50 Iteration: 280 -> Validation loss: 0.310642 Validation acc: 0.916767 Validation f1-score: [0.94362341 0.91175059 0.90561947 0.90560096]
# Epoch: 5/50 Iteration: 290 -> Validation loss: 0.307413 Validation acc: 0.912260 Validation f1-score: [0.93410963 0.90994209 0.9090611  0.89556113]
# Epoch: 5/50 Iteration: 300 -> Train loss: 0.320113 | Train acc: 0.906250 | Train f1-score: [0.70314441 0.74198492 0.70318457 0.65450694]
# Epoch: 5/50 Iteration: 300 -> Validation loss: 0.294551 Validation acc: 0.916767 Validation f1-score: [0.9238596  0.92602021 0.92212412 0.89428209]
# Epoch: 5/50 Iteration: 310 -> Validation loss: 0.273906 Validation acc: 0.927584 Validation f1-score: [0.94648011 0.92480489 0.92143789 0.91708306]
# Epoch: 6/50 Iteration: 320 -> Train loss: 0.253750 | Train acc: 0.933594 | Train f1-score: [0.71847476 0.7537029  0.71674568 0.67067949]
# Epoch: 6/50 Iteration: 320 -> Validation loss: 0.266885 Validation acc: 0.932091 Validation f1-score: [0.95304879 0.92486167 0.9194079  0.9292869 ]
# Epoch: 6/50 Iteration: 330 -> Validation loss: 0.256298 Validation acc: 0.937200 Validation f1-score: [0.95914197 0.92678935 0.92928983 0.93346031]
# Epoch: 6/50 Iteration: 340 -> Train loss: 0.236134 | Train acc: 0.941406 | Train f1-score: [0.73288062 0.76402683 0.72933972 0.68577758]
# Epoch: 6/50 Iteration: 340 -> Validation loss: 0.243505 Validation acc: 0.942608 Validation f1-score: [0.96166306 0.93686714 0.93257442 0.93811256]
# Epoch: 6/50 Iteration: 350 -> Validation loss: 0.234665 Validation acc: 0.943209 Validation f1-score: [0.9578933  0.93833744 0.93617197 0.93878403]
# Epoch: 6/50 Iteration: 360 -> Train loss: 0.220989 | Train acc: 0.949219 | Train f1-score: [0.74538801 0.77398037 0.7413603  0.69919009]
# Epoch: 6/50 Iteration: 360 -> Validation loss: 0.223300 Validation acc: 0.944111 Validation f1-score: [0.96129775 0.93720756 0.93786825 0.93913357]
# Epoch: 6/50 Iteration: 370 -> Validation loss: 0.225575 Validation acc: 0.943810 Validation f1-score: [0.9659679  0.94434415 0.92858869 0.93426038]
# Epoch: 7/50 Iteration: 380 -> Train loss: 0.158046 | Train acc: 0.980469 | Train f1-score: [0.75714513 0.78312955 0.75225084 0.711957  ]
# Epoch: 7/50 Iteration: 380 -> Validation loss: 0.210624 Validation acc: 0.953726 Validation f1-score: [0.97283644 0.94646286 0.94563121 0.94865097]
# Epoch: 7/50 Iteration: 390 -> Validation loss: 0.196057 Validation acc: 0.957933 Validation f1-score: [0.97408554 0.95036537 0.95138398 0.95482295]
# Epoch: 7/50 Iteration: 400 -> Train loss: 0.178599 | Train acc: 0.964844 | Train f1-score: [0.76778527 0.79156716 0.76194784 0.72408626]
# Epoch: 7/50 Iteration: 400 -> Validation loss: 0.197695 Validation acc: 0.952224 Validation f1-score: [0.96775895 0.94480728 0.9486034  0.94641925]
# Epoch: 7/50 Iteration: 410 -> Validation loss: 0.191008 Validation acc: 0.958233 Validation f1-score: [0.96528233 0.95604611 0.95236242 0.95682722]
# Epoch: 7/50 Iteration: 420 -> Train loss: 0.140314 | Train acc: 0.984375 | Train f1-score: [0.77743893 0.79932823 0.77146254 0.7348573 ]
# Epoch: 7/50 Iteration: 420 -> Validation loss: 0.177043 Validation acc: 0.961839 Validation f1-score: [0.97357949 0.95540693 0.95863821 0.95877725]
# Epoch: 8/50 Iteration: 430 -> Validation loss: 0.175207 Validation acc: 0.961538 Validation f1-score: [0.97318455 0.95972744 0.95151023 0.96121148]
# Epoch: 8/50 Iteration: 440 -> Train loss: 0.180776 | Train acc: 0.960938 | Train f1-score: [0.78637555 0.80669138 0.77983107 0.74511005]
# Epoch: 8/50 Iteration: 440 -> Validation loss: 0.161832 Validation acc: 0.969050 Validation f1-score: [0.97718497 0.96358216 0.963977   0.97050156]
# Epoch: 8/50 Iteration: 450 -> Validation loss: 0.161657 Validation acc: 0.966647 Validation f1-score: [0.97315286 0.96470835 0.96318108 0.96480118]
# Epoch: 8/50 Iteration: 460 -> Train loss: 0.174477 | Train acc: 0.937500 | Train f1-score: [0.79450304 0.81364286 0.78795101 0.75450786]
# Epoch: 8/50 Iteration: 460 -> Validation loss: 0.160230 Validation acc: 0.965745 Validation f1-score: [0.97259982 0.96248945 0.96152842 0.96607102]
# Epoch: 8/50 Iteration: 470 -> Validation loss: 0.160744 Validation acc: 0.963041 Validation f1-score: [0.97719613 0.95853536 0.95271405 0.96295241]
# Epoch: 9/50 Iteration: 480 -> Train loss: 0.120867 | Train acc: 0.964844 | Train f1-score: [0.80205696 0.82020848 0.79543834 0.76309535]
# Epoch: 9/50 Iteration: 480 -> Validation loss: 0.143103 Validation acc: 0.973257 Validation f1-score: [0.98315156 0.9665366  0.96630054 0.97572263]
# Epoch: 9/50 Iteration: 490 -> Validation loss: 0.139757 Validation acc: 0.971154 Validation f1-score: [0.98143478 0.96432294 0.96565424 0.97213222]
# Epoch: 9/50 Iteration: 500 -> Train loss: 0.130943 | Train acc: 0.972656 | Train f1-score: [0.80922485 0.82624079 0.8023092  0.77148601]
# Epoch: 9/50 Iteration: 500 -> Validation loss: 0.139687 Validation acc: 0.969651 Validation f1-score: [0.97791039 0.96456041 0.96410895 0.97068102]
# Epoch: 9/50 Iteration: 510 -> Validation loss: 0.136427 Validation acc: 0.968750 Validation f1-score: [0.97676489 0.96617268 0.96310216 0.96843323]
# Epoch: 9/50 Iteration: 520 -> Train loss: 0.146381 | Train acc: 0.964844 | Train f1-score: [0.81579602 0.83180289 0.80879422 0.77912766]
# Epoch: 9/50 Iteration: 520 -> Validation loss: 0.125430 Validation acc: 0.976262 Validation f1-score: [0.98056452 0.9750127  0.97348795 0.97460251]
# Epoch: 9/50 Iteration: 530 -> Validation loss: 0.133728 Validation acc: 0.972656 Validation f1-score: [0.97925956 0.97204707 0.96757114 0.9701454 ]
# Epoch: 10/50 Iteration: 540 -> Train loss: 0.116016 | Train acc: 0.984375 | Train f1-score: [0.82188621 0.83724653 0.81516193 0.78645656]
# Epoch: 10/50 Iteration: 540 -> Validation loss: 0.129335 Validation acc: 0.975661 Validation f1-score: [0.97872494 0.97143528 0.97288231 0.97819372]
# Epoch: 10/50 Iteration: 550 -> Validation loss: 0.117666 Validation acc: 0.977764 Validation f1-score: [0.98430802 0.97340002 0.97272003 0.97946469]
# Epoch: 10/50 Iteration: 560 -> Train loss: 0.099818 | Train acc: 0.984375 | Train f1-score: [0.82776541 0.84232559 0.82086027 0.79340526]
# Epoch: 10/50 Iteration: 560 -> Validation loss: 0.128955 Validation acc: 0.975361 Validation f1-score: [0.98014394 0.97133084 0.97363277 0.97483792]
# Epoch: 10/50 Iteration: 570 -> Validation loss: 0.122165 Validation acc: 0.975361 Validation f1-score: [0.97597298 0.97450399 0.97492123 0.97409844]
# Epoch: 10/50 Iteration: 580 -> Train loss: 0.086275 | Train acc: 0.984375 | Train f1-score: [0.83305146 0.84713312 0.82642218 0.79945909]
# Epoch: 10/50 Iteration: 580 -> Validation loss: 0.105517 Validation acc: 0.979868 Validation f1-score: [0.98325729 0.9785323  0.9792461  0.97718588]
# Epoch: 11/50 Iteration: 590 -> Validation loss: 0.104557 Validation acc: 0.978666 Validation f1-score: [0.98383566 0.97451837 0.97577182 0.97964776]
# Epoch: 11/50 Iteration: 600 -> Train loss: 0.077878 | Train acc: 0.988281 | Train f1-score: [0.83803597 0.85150294 0.83145368 0.80549997]
# Epoch: 11/50 Iteration: 600 -> Validation loss: 0.105840 Validation acc: 0.977464 Validation f1-score: [0.9820911  0.97394922 0.97341284 0.97952585]
# Epoch: 11/50 Iteration: 610 -> Validation loss: 0.108266 Validation acc: 0.976562 Validation f1-score: [0.97855547 0.97915963 0.97406712 0.97337131]
# Epoch: 11/50 Iteration: 620 -> Train loss: 0.106715 | Train acc: 0.968750 | Train f1-score: [0.84274156 0.8557088  0.83629164 0.81110906]
# Epoch: 11/50 Iteration: 620 -> Validation loss: 0.103821 Validation acc: 0.977163 Validation f1-score: [0.98043358 0.97578682 0.97520139 0.97638958]
# Epoch: 11/50 Iteration: 630 -> Validation loss: 0.105953 Validation acc: 0.975962 Validation f1-score: [0.98142072 0.97504686 0.97258454 0.97366349]
# Epoch: 12/50 Iteration: 640 -> Train loss: 0.094337 | Train acc: 0.984375 | Train f1-score: [0.84712798 0.85975467 0.84090171 0.81639178]
# Epoch: 12/50 Iteration: 640 -> Validation loss: 0.092852 Validation acc: 0.983474 Validation f1-score: [0.98486137 0.98180461 0.98441661 0.98199978]
# Epoch: 12/50 Iteration: 650 -> Validation loss: 0.092913 Validation acc: 0.982572 Validation f1-score: [0.98444731 0.98141033 0.98122349 0.98242569]
# Epoch: 12/50 Iteration: 660 -> Train loss: 0.069894 | Train acc: 0.988281 | Train f1-score: [0.85142621 0.8634883  0.84525797 0.82157628]
# Epoch: 12/50 Iteration: 660 -> Validation loss: 0.093218 Validation acc: 0.981971 Validation f1-score: [0.98183592 0.98213853 0.98123109 0.98141509]
# Epoch: 12/50 Iteration: 670 -> Validation loss: 0.091104 Validation acc: 0.981370 Validation f1-score: [0.98014781 0.98308571 0.98435768 0.97714025]
# Epoch: 12/50 Iteration: 680 -> Train loss: 0.068201 | Train acc: 0.984375 | Train f1-score: [0.85530872 0.86713269 0.84939583 0.82618654]
# Epoch: 12/50 Iteration: 680 -> Validation loss: 0.087548 Validation acc: 0.981370 Validation f1-score: [0.9813599  0.98156446 0.98168846 0.97954884]
# Epoch: 13/50 Iteration: 690 -> Validation loss: 0.093212 Validation acc: 0.983173 Validation f1-score: [0.98471875 0.98389477 0.98440634 0.97795569]
# Epoch: 13/50 Iteration: 700 -> Train loss: 0.050407 | Train acc: 0.996094 | Train f1-score: [0.85915216 0.8705939  0.8533091  0.83068036]
# Epoch: 13/50 Iteration: 700 -> Validation loss: 0.094214 Validation acc: 0.982272 Validation f1-score: [0.98615596 0.97865136 0.98125363 0.98182623]
# Epoch: 13/50 Iteration: 710 -> Validation loss: 0.089067 Validation acc: 0.981971 Validation f1-score: [0.98487764 0.97877499 0.97887953 0.98426   ]
# Epoch: 13/50 Iteration: 720 -> Train loss: 0.070360 | Train acc: 0.988281 | Train f1-score: [0.86266958 0.87378288 0.85699203 0.83493687]
# Epoch: 13/50 Iteration: 720 -> Validation loss: 0.094377 Validation acc: 0.981370 Validation f1-score: [0.98114503 0.98326522 0.98146267 0.97864777]
# Epoch: 13/50 Iteration: 730 -> Validation loss: 0.105870 Validation acc: 0.975361 Validation f1-score: [0.97745051 0.98032428 0.97218234 0.9700249 ]
# Epoch: 13/50 Iteration: 740 -> Train loss: 0.072674 | Train acc: 0.992188 | Train f1-score: [0.86603201 0.8767813  0.8603915  0.83869107]
# Epoch: 13/50 Iteration: 740 -> Validation loss: 0.081749 Validation acc: 0.984075 Validation f1-score: [0.98640476 0.98136221 0.98137117 0.98584138]
# Epoch: 14/50 Iteration: 750 -> Validation loss: 0.087765 Validation acc: 0.983774 Validation f1-score: [0.98343653 0.98353608 0.9828494  0.98426088]
# Epoch: 14/50 Iteration: 760 -> Train loss: 0.075747 | Train acc: 0.992188 | Train f1-score: [0.86923381 0.87968361 0.86378219 0.84250199]
# Epoch: 14/50 Iteration: 760 -> Validation loss: 0.084166 Validation acc: 0.980469 Validation f1-score: [0.98326694 0.9792374  0.97775569 0.98062319]
# Epoch: 14/50 Iteration: 770 -> Validation loss: 0.083973 Validation acc: 0.981671 Validation f1-score: [0.98215978 0.98334953 0.98205447 0.97842537]
# Epoch: 14/50 Iteration: 780 -> Train loss: 0.066756 | Train acc: 0.988281 | Train f1-score: [0.87229254 0.88248216 0.86694202 0.84611844]
# Epoch: 14/50 Iteration: 780 -> Validation loss: 0.090828 Validation acc: 0.978966 Validation f1-score: [0.97951898 0.98251393 0.98032315 0.97234705]
# Epoch: 14/50 Iteration: 790 -> Validation loss: 0.079731 Validation acc: 0.981370 Validation f1-score: [0.98267169 0.98140187 0.98206223 0.97812116]
# Epoch: 15/50 Iteration: 800 -> Train loss: 0.079672 | Train acc: 0.992188 | Train f1-score: [0.87525283 0.8851976  0.86996835 0.84949302]
# Epoch: 15/50 Iteration: 800 -> Validation loss: 0.073636 Validation acc: 0.984375 Validation f1-score: [0.98416696 0.98443817 0.98329298 0.98487026]
# Epoch: 15/50 Iteration: 810 -> Validation loss: 0.075809 Validation acc: 0.984075 Validation f1-score: [0.98916285 0.98124693 0.97864359 0.98679452]
# Epoch: 15/50 Iteration: 820 -> Train loss: 0.060637 | Train acc: 0.984375 | Train f1-score: [0.87807918 0.8876709  0.8728264  0.8528709 ]
# Epoch: 15/50 Iteration: 820 -> Validation loss: 0.071346 Validation acc: 0.986178 Validation f1-score: [0.98719703 0.98448108 0.98469358 0.98700816]
# Epoch: 15/50 Iteration: 830 -> Validation loss: 0.070382 Validation acc: 0.985276 Validation f1-score: [0.98355376 0.9849001  0.98727382 0.98398168]
# Epoch: 15/50 Iteration: 840 -> Train loss: 0.051548 | Train acc: 0.988281 | Train f1-score: [0.88078215 0.89009838 0.87561147 0.85596159]
# Epoch: 15/50 Iteration: 840 -> Validation loss: 0.085334 Validation acc: 0.981070 Validation f1-score: [0.98534584 0.97930002 0.98049436 0.97760961]
# Epoch: 16/50 Iteration: 850 -> Validation loss: 0.079892 Validation acc: 0.984075 Validation f1-score: [0.98544751 0.98373229 0.98543243 0.98010376]
# Epoch: 16/50 Iteration: 860 -> Train loss: 0.043817 | Train acc: 0.988281 | Train f1-score: [0.88335361 0.89241762 0.87825279 0.85897676]
# Epoch: 16/50 Iteration: 860 -> Validation loss: 0.073189 Validation acc: 0.985877 Validation f1-score: [0.98545915 0.98485236 0.98347029 0.98852818]
# Epoch: 16/50 Iteration: 870 -> Validation loss: 0.070057 Validation acc: 0.985877 Validation f1-score: [0.98451796 0.98601595 0.98660078 0.98550584]
# Epoch: 16/50 Iteration: 880 -> Train loss: 0.046053 | Train acc: 0.996094 | Train f1-score: [0.88577475 0.89459967 0.88078324 0.86197586]
# Epoch: 16/50 Iteration: 880 -> Validation loss: 0.078898 Validation acc: 0.981971 Validation f1-score: [0.98547868 0.97719334 0.98150152 0.98248315]
# Epoch: 16/50 Iteration: 890 -> Validation loss: 0.087457 Validation acc: 0.978065 Validation f1-score: [0.98116194 0.98207749 0.97286062 0.9752823 ]
# Epoch: 16/50 Iteration: 900 -> Train loss: 0.029041 | Train acc: 1.000000 | Train f1-score: [0.88808338 0.89671385 0.88312761 0.86459329]
# Epoch: 16/50 Iteration: 900 -> Validation loss: 0.065613 Validation acc: 0.984675 Validation f1-score: [0.9876247  0.98223662 0.97997375 0.98787133]
# Epoch: 17/50 Iteration: 910 -> Validation loss: 0.076276 Validation acc: 0.984075 Validation f1-score: [0.98371772 0.98371997 0.98476413 0.98341488]
# Epoch: 17/50 Iteration: 920 -> Train loss: 0.038376 | Train acc: 0.992188 | Train f1-score: [0.8903244  0.89872561 0.8854235  0.86730611]
# Epoch: 17/50 Iteration: 920 -> Validation loss: 0.066102 Validation acc: 0.984976 Validation f1-score: [0.98387018 0.98506206 0.98525082 0.98515821]
# Epoch: 17/50 Iteration: 930 -> Validation loss: 0.064386 Validation acc: 0.984075 Validation f1-score: [0.98392752 0.98251852 0.98543355 0.98399292]
# Epoch: 17/50 Iteration: 940 -> Train loss: 0.065543 | Train acc: 0.976562 | Train f1-score: [0.89253081 0.90066015 0.88765259 0.86987836]
# Epoch: 17/50 Iteration: 940 -> Validation loss: 0.064385 Validation acc: 0.985877 Validation f1-score: [0.98419891 0.98430188 0.98933137 0.98514198]
# Epoch: 17/50 Iteration: 950 -> Validation loss: 0.073146 Validation acc: 0.981671 Validation f1-score: [0.98429348 0.97827669 0.98713929 0.97646512]
# Epoch: 18/50 Iteration: 960 -> Train loss: 0.060464 | Train acc: 0.980469 | Train f1-score: [0.89456975 0.90255763 0.88980009 0.87231749]
# Epoch: 18/50 Iteration: 960 -> Validation loss: 0.066319 Validation acc: 0.985276 Validation f1-score: [0.9853898  0.98611098 0.9824237  0.9866071 ]
# Epoch: 18/50 Iteration: 970 -> Validation loss: 0.064585 Validation acc: 0.987981 Validation f1-score: [0.98799045 0.98720683 0.98737804 0.9883988 ]
# Epoch: 18/50 Iteration: 980 -> Train loss: 0.035654 | Train acc: 0.996094 | Train f1-score: [0.89655816 0.90437797 0.89189808 0.87476079]
# Epoch: 18/50 Iteration: 980 -> Validation loss: 0.057767 Validation acc: 0.987981 Validation f1-score: [0.98962898 0.98608155 0.98604857 0.98924126]
# Epoch: 18/50 Iteration: 990 -> Validation loss: 0.058967 Validation acc: 0.984075 Validation f1-score: [0.98362061 0.98322458 0.98399347 0.98501417]
# Epoch: 18/50 Iteration: 1000 -> Train loss: 0.036920 | Train acc: 0.992188 | Train f1-score: [0.89849196 0.90612631 0.89392511 0.87709083]
# Epoch: 18/50 Iteration: 1000 -> Validation loss: 0.060457 Validation acc: 0.983474 Validation f1-score: [0.98614901 0.98295002 0.9781064  0.98620089]
# Epoch: 19/50 Iteration: 1010 -> Validation loss: 0.068399 Validation acc: 0.984976 Validation f1-score: [0.98508895 0.98593905 0.98399234 0.98357357]
# Epoch: 19/50 Iteration: 1020 -> Train loss: 0.068810 | Train acc: 0.988281 | Train f1-score: [0.90034444 0.90780057 0.89585918 0.87932821]
# Epoch: 19/50 Iteration: 1020 -> Validation loss: 0.061807 Validation acc: 0.988582 Validation f1-score: [0.98718457 0.98771474 0.98893526 0.99002092]
# Epoch: 19/50 Iteration: 1030 -> Validation loss: 0.052470 Validation acc: 0.987981 Validation f1-score: [0.98798714 0.98616486 0.98958807 0.98736008]
# Epoch: 19/50 Iteration: 1040 -> Train loss: 0.035591 | Train acc: 0.992188 | Train f1-score: [0.9021886  0.9094705  0.89778018 0.88151586]
# Epoch: 19/50 Iteration: 1040 -> Validation loss: 0.057705 Validation acc: 0.987680 Validation f1-score: [0.98921965 0.98519576 0.98771259 0.98778416]
# Epoch: 19/50 Iteration: 1050 -> Validation loss: 0.070115 Validation acc: 0.983774 Validation f1-score: [0.98662287 0.98281954 0.98612811 0.97804342]
# Epoch: 19/50 Iteration: 1060 -> Train loss: 0.022290 | Train acc: 1.000000 | Train f1-score: [0.90390933 0.91101661 0.89955932 0.88351468]
# Epoch: 19/50 Iteration: 1060 -> Validation loss: 0.063608 Validation acc: 0.987079 Validation f1-score: [0.98822095 0.98245475 0.98567424 0.9909321 ]
# Epoch: 20/50 Iteration: 1070 -> Validation loss: 0.073283 Validation acc: 0.984075 Validation f1-score: [0.98649737 0.98364153 0.97964167 0.98564586]
# Epoch: 20/50 Iteration: 1080 -> Train loss: 0.029858 | Train acc: 0.992188 | Train f1-score: [0.90552624 0.91247097 0.90114199 0.88549397]
# Epoch: 20/50 Iteration: 1080 -> Validation loss: 0.050718 Validation acc: 0.988882 Validation f1-score: [0.98968628 0.98704066 0.98860005 0.98915037]
# Epoch: 20/50 Iteration: 1090 -> Validation loss: 0.050211 Validation acc: 0.987981 Validation f1-score: [0.98625066 0.98904435 0.98955813 0.98615028]
# Epoch: 20/50 Iteration: 1100 -> Train loss: 0.043632 | Train acc: 0.992188 | Train f1-score: [0.90714454 0.91390165 0.90282359 0.88744681]
# Epoch: 20/50 Iteration: 1100 -> Validation loss: 0.053544 Validation acc: 0.987380 Validation f1-score: [0.98483637 0.98820208 0.99036129 0.98508756]
# Epoch: 20/50 Iteration: 1110 -> Validation loss: 0.067425 Validation acc: 0.980469 Validation f1-score: [0.98495484 0.97379448 0.98293632 0.97997051]
# Epoch: 21/50 Iteration: 1120 -> Train loss: 0.051059 | Train acc: 0.992188 | Train f1-score: [0.90866086 0.91530103 0.90438129 0.88924308]
# Epoch: 21/50 Iteration: 1120 -> Validation loss: 0.064505 Validation acc: 0.983173 Validation f1-score: [0.98757501 0.98064227 0.9753719  0.98870984]
# Epoch: 21/50 Iteration: 1130 -> Validation loss: 0.051454 Validation acc: 0.989183 Validation f1-score: [0.99093871 0.98731142 0.98913748 0.98845604]
# Epoch: 21/50 Iteration: 1140 -> Train loss: 0.026909 | Train acc: 0.996094 | Train f1-score: [0.91009754 0.91663251 0.90588285 0.89104106]
# Epoch: 21/50 Iteration: 1140 -> Validation loss: 0.055121 Validation acc: 0.987981 Validation f1-score: [0.98904184 0.98676354 0.98582022 0.98931857]
# Epoch: 21/50 Iteration: 1150 -> Validation loss: 0.051168 Validation acc: 0.987680 Validation f1-score: [0.98570528 0.9877129  0.99024996 0.98646929]
# Epoch: 21/50 Iteration: 1160 -> Train loss: 0.052116 | Train acc: 0.988281 | Train f1-score: [0.911572   0.91791884 0.90738311 0.89275682]
# Epoch: 21/50 Iteration: 1160 -> Validation loss: 0.053829 Validation acc: 0.987981 Validation f1-score: [0.99093871 0.98345398 0.98535579 0.99175157]
# Epoch: 22/50 Iteration: 1170 -> Validation loss: 0.066765 Validation acc: 0.986178 Validation f1-score: [0.98962337 0.98611585 0.98683821 0.98074491]
# Epoch: 22/50 Iteration: 1180 -> Train loss: 0.047474 | Train acc: 0.980469 | Train f1-score: [0.912942   0.91914023 0.90879177 0.89440639]
# Epoch: 22/50 Iteration: 1180 -> Validation loss: 0.050177 Validation acc: 0.989784 Validation f1-score: [0.98966185 0.98724776 0.98976982 0.9919226 ]
# Epoch: 22/50 Iteration: 1190 -> Validation loss: 0.047486 Validation acc: 0.988882 Validation f1-score: [0.98897175 0.98780873 0.98808388 0.98978786]
# Epoch: 22/50 Iteration: 1200 -> Train loss: 0.020358 | Train acc: 0.996094 | Train f1-score: [0.91431853 0.92041899 0.91026283 0.89609341]
# Epoch: 22/50 Iteration: 1200 -> Validation loss: 0.045248 Validation acc: 0.989784 Validation f1-score: [0.98843634 0.9888716  0.99039079 0.99030679]
# Epoch: 22/50 Iteration: 1210 -> Validation loss: 0.047962 Validation acc: 0.988882 Validation f1-score: [0.98928726 0.98729144 0.98899271 0.98895405]
# Epoch: 23/50 Iteration: 1220 -> Train loss: 0.027412 | Train acc: 0.996094 | Train f1-score: [0.91563975 0.92164213 0.91162978 0.8976593 ]
# Epoch: 23/50 Iteration: 1220 -> Validation loss: 0.045109 Validation acc: 0.988882 Validation f1-score: [0.98870007 0.98597391 0.99074004 0.98943227]
# Epoch: 23/50 Iteration: 1230 -> Validation loss: 0.044527 Validation acc: 0.991286 Validation f1-score: [0.99038522 0.99031222 0.99271272 0.99136445]
# Epoch: 23/50 Iteration: 1240 -> Train loss: 0.024210 | Train acc: 0.996094 | Train f1-score: [0.91691433 0.92280533 0.91295442 0.89919918]
# Epoch: 23/50 Iteration: 1240 -> Validation loss: 0.044987 Validation acc: 0.989483 Validation f1-score: [0.99011265 0.98902943 0.98857385 0.98919178]
# Epoch: 23/50 Iteration: 1250 -> Validation loss: 0.046719 Validation acc: 0.988882 Validation f1-score: [0.98839359 0.98847033 0.98856056 0.98917256]
# Epoch: 23/50 Iteration: 1260 -> Train loss: 0.025990 | Train acc: 0.996094 | Train f1-score: [0.91813843 0.92390106 0.91419248 0.90064703]
# Epoch: 23/50 Iteration: 1260 -> Validation loss: 0.048293 Validation acc: 0.987680 Validation f1-score: [0.98553617 0.98728401 0.98981129 0.98740929]
# Epoch: 23/50 Iteration: 1270 -> Validation loss: 0.063778 Validation acc: 0.981971 Validation f1-score: [0.98489192 0.97453173 0.98861902 0.97957138]
# Epoch: 24/50 Iteration: 1280 -> Train loss: 0.029793 | Train acc: 0.996094 | Train f1-score: [0.91931355 0.92495911 0.91543094 0.90206113]
# Epoch: 24/50 Iteration: 1280 -> Validation loss: 0.056531 Validation acc: 0.985877 Validation f1-score: [0.98876709 0.98486285 0.97840531 0.99113557]
# Epoch: 24/50 Iteration: 1290 -> Validation loss: 0.045541 Validation acc: 0.989784 Validation f1-score: [0.99139639 0.98715784 0.98916993 0.9904706 ]
# Epoch: 24/50 Iteration: 1300 -> Train loss: 0.016297 | Train acc: 1.000000 | Train f1-score: [0.92048315 0.9260516  0.91665344 0.90350994]
# Epoch: 24/50 Iteration: 1300 -> Validation loss: 0.056123 Validation acc: 0.986478 Validation f1-score: [0.98745845 0.98618    0.9845675  0.98690166]
# Epoch: 24/50 Iteration: 1310 -> Validation loss: 0.056396 Validation acc: 0.986178 Validation f1-score: [0.98531181 0.98726915 0.98837664 0.9828994 ]
# Epoch: 24/50 Iteration: 1320 -> Train loss: 0.063855 | Train acc: 0.980469 | Train f1-score: [0.92160207 0.92704403 0.91778582 0.90477382]
# Epoch: 24/50 Iteration: 1320 -> Validation loss: 0.041943 Validation acc: 0.988882 Validation f1-score: [0.98727141 0.98843    0.99097571 0.98821775]
# Epoch: 25/50 Iteration: 1330 -> Validation loss: 0.057065 Validation acc: 0.987079 Validation f1-score: [0.98955116 0.9849466  0.98796349 0.98469737]
# Epoch: 25/50 Iteration: 1340 -> Train loss: 0.024237 | Train acc: 1.000000 | Train f1-score: [0.92269948 0.92800175 0.91890772 0.90605658]
# Epoch: 25/50 Iteration: 1340 -> Validation loss: 0.047908 Validation acc: 0.990685 Validation f1-score: [0.98858185 0.98950456 0.99146361 0.99237933]
# Epoch: 25/50 Iteration: 1350 -> Validation loss: 0.045547 Validation acc: 0.991587 Validation f1-score: [0.99091504 0.99031855 0.99152062 0.99313503]
# Epoch: 25/50 Iteration: 1360 -> Train loss: 0.045349 | Train acc: 0.980469 | Train f1-score: [0.92378271 0.92899575 0.92004859 0.90736659]
# Epoch: 25/50 Iteration: 1360 -> Validation loss: 0.043705 Validation acc: 0.988281 Validation f1-score: [0.98782379 0.98737296 0.98739776 0.98978786]
# Epoch: 25/50 Iteration: 1370 -> Validation loss: 0.043669 Validation acc: 0.988582 Validation f1-score: [0.98789095 0.98725446 0.98852243 0.98978736]
# Epoch: 26/50 Iteration: 1380 -> Train loss: 0.025931 | Train acc: 0.992188 | Train f1-score: [0.92480685 0.92997526 0.9211399  0.90861363]
# Epoch: 26/50 Iteration: 1380 -> Validation loss: 0.044354 Validation acc: 0.989183 Validation f1-score: [0.98697963 0.98768904 0.99155957 0.99000207]
# Epoch: 26/50 Iteration: 1390 -> Validation loss: 0.038491 Validation acc: 0.990685 Validation f1-score: [0.98975429 0.98844858 0.99204952 0.99149078]
# Epoch: 26/50 Iteration: 1400 -> Train loss: 0.017504 | Train acc: 0.996094 | Train f1-score: [0.92581307 0.9308555  0.92219597 0.90985358]
# Epoch: 26/50 Iteration: 1400 -> Validation loss: 0.046598 Validation acc: 0.989483 Validation f1-score: [0.9883498  0.98970492 0.9892075  0.98978786]
# Epoch: 26/50 Iteration: 1410 -> Validation loss: 0.041111 Validation acc: 0.990986 Validation f1-score: [0.99036553 0.98959148 0.99208116 0.99102155]
# Epoch: 26/50 Iteration: 1420 -> Train loss: 0.040321 | Train acc: 0.988281 | Train f1-score: [0.92681046 0.93176133 0.92321286 0.91103052]
# Epoch: 26/50 Iteration: 1420 -> Validation loss: 0.039307 Validation acc: 0.988582 Validation f1-score: [0.98789095 0.98725424 0.98916294 0.98907785]
# Epoch: 26/50 Iteration: 1430 -> Validation loss: 0.041366 Validation acc: 0.990385 Validation f1-score: [0.98972185 0.98932839 0.9921356  0.98966   ]
# Epoch: 27/50 Iteration: 1440 -> Train loss: 0.016625 | Train acc: 0.996094 | Train f1-score: [0.92776691 0.9326621  0.92422994 0.91218395]
# Epoch: 27/50 Iteration: 1440 -> Validation loss: 0.040547 Validation acc: 0.992488 Validation f1-score: [0.99133059 0.99029112 0.99283221 0.99484456]
# Epoch: 27/50 Iteration: 1450 -> Validation loss: 0.042716 Validation acc: 0.989784 Validation f1-score: [0.99057032 0.98910985 0.98800196 0.99043175]
# Epoch: 27/50 Iteration: 1460 -> Train loss: 0.017682 | Train acc: 1.000000 | Train f1-score: [0.92871725 0.93353449 0.92520591 0.91333993]
# Epoch: 27/50 Iteration: 1460 -> Validation loss: 0.054555 Validation acc: 0.986779 Validation f1-score: [0.98789016 0.98772859 0.98436469 0.9861968 ]
# Epoch: 27/50 Iteration: 1470 -> Validation loss: 0.046681 Validation acc: 0.987680 Validation f1-score: [0.98787708 0.98733771 0.98710381 0.98766817]
# Epoch: 27/50 Iteration: 1480 -> Train loss: 0.020396 | Train acc: 0.996094 | Train f1-score: [0.92963268 0.93430889 0.92612059 0.91438128]
# Epoch: 27/50 Iteration: 1480 -> Validation loss: 0.040359 Validation acc: 0.990084 Validation f1-score: [0.98929538 0.98864972 0.9917067  0.9900165 ]
# Epoch: 28/50 Iteration: 1490 -> Validation loss: 0.058073 Validation acc: 0.987380 Validation f1-score: [0.98798571 0.98833137 0.9863257  0.98601265]
# Epoch: 28/50 Iteration: 1500 -> Train loss: 0.036884 | Train acc: 0.996094 | Train f1-score: [0.93050286 0.93506163 0.92700193 0.91541158]
# Epoch: 28/50 Iteration: 1500 -> Validation loss: 0.042393 Validation acc: 0.989483 Validation f1-score: [0.9893395  0.98761482 0.98905785 0.99118558]
# Epoch: 28/50 Iteration: 1510 -> Validation loss: 0.047083 Validation acc: 0.987680 Validation f1-score: [0.98986802 0.98792065 0.98503028 0.98701435]
# Epoch: 28/50 Iteration: 1520 -> Train loss: 0.021804 | Train acc: 0.996094 | Train f1-score: [0.93137209 0.93587253 0.92789891 0.9164669 ]
# Epoch: 28/50 Iteration: 1520 -> Validation loss: 0.038786 Validation acc: 0.989183 Validation f1-score: [0.98785014 0.98914186 0.98972413 0.98907594]
# Epoch: 28/50 Iteration: 1530 -> Validation loss: 0.044710 Validation acc: 0.990084 Validation f1-score: [0.98986527 0.98942508 0.99091604 0.98901133]
# Epoch: 29/50 Iteration: 1540 -> Train loss: 0.019734 | Train acc: 0.996094 | Train f1-score: [0.93222436 0.93665998 0.92878897 0.9174601 ]
# Epoch: 29/50 Iteration: 1540 -> Validation loss: 0.038734 Validation acc: 0.990685 Validation f1-score: [0.99045172 0.98882716 0.99081815 0.99149078]
# Epoch: 29/50 Iteration: 1550 -> Validation loss: 0.035662 Validation acc: 0.992188 Validation f1-score: [0.99023186 0.99006027 0.99272306 0.99498174]
# Epoch: 29/50 Iteration: 1560 -> Train loss: 0.011235 | Train acc: 1.000000 | Train f1-score: [0.93304579 0.9374146  0.92964764 0.91845662]
# Epoch: 29/50 Iteration: 1560 -> Validation loss: 0.037123 Validation acc: 0.990986 Validation f1-score: [0.99072513 0.98904026 0.9903807  0.99295287]
# Epoch: 29/50 Iteration: 1570 -> Validation loss: 0.042235 Validation acc: 0.989784 Validation f1-score: [0.99050397 0.98676362 0.98888494 0.99234765]
# Epoch: 29/50 Iteration: 1580 -> Train loss: 0.013072 | Train acc: 1.000000 | Train f1-score: [0.93385584 0.93816467 0.93049559 0.91942934]
# Epoch: 29/50 Iteration: 1580 -> Validation loss: 0.039328 Validation acc: 0.990084 Validation f1-score: [0.99051995 0.9872455  0.99010378 0.99160778]
# Epoch: 29/50 Iteration: 1590 -> Validation loss: 0.038902 Validation acc: 0.990084 Validation f1-score: [0.98843042 0.98891221 0.99172713 0.99061529]
# Epoch: 30/50 Iteration: 1600 -> Train loss: 0.026435 | Train acc: 0.988281 | Train f1-score: [0.93464971 0.93888107 0.93132077 0.92037204]
# Epoch: 30/50 Iteration: 1600 -> Validation loss: 0.035656 Validation acc: 0.991286 Validation f1-score: [0.99071648 0.99038542 0.99099633 0.99221332]
# Epoch: 30/50 Iteration: 1610 -> Validation loss: 0.035041 Validation acc: 0.991887 Validation f1-score: [0.99161885 0.98914362 0.99375267 0.99226026]
# Epoch: 30/50 Iteration: 1620 -> Train loss: 0.015645 | Train acc: 0.996094 | Train f1-score: [0.93542593 0.93960865 0.93212629 0.92131887]
# Epoch: 30/50 Iteration: 1620 -> Validation loss: 0.051655 Validation acc: 0.987079 Validation f1-score: [0.98919942 0.98886128 0.98440586 0.98506106]
# Epoch: 30/50 Iteration: 1630 -> Validation loss: 0.041939 Validation acc: 0.987680 Validation f1-score: [0.98783419 0.98809471 0.98647978 0.9875812 ]
# Epoch: 30/50 Iteration: 1640 -> Train loss: 0.008517 | Train acc: 1.000000 | Train f1-score: [0.93618613 0.94029451 0.9329142  0.92222673]
# Epoch: 30/50 Iteration: 1640 -> Validation loss: 0.034927 Validation acc: 0.991286 Validation f1-score: [0.99071648 0.9903415  0.99034952 0.99283863]
# Epoch: 31/50 Iteration: 1650 -> Validation loss: 0.039537 Validation acc: 0.990385 Validation f1-score: [0.99064968 0.989605   0.98993019 0.99089447]
# Epoch: 31/50 Iteration: 1660 -> Train loss: 0.031309 | Train acc: 0.992188 | Train f1-score: [0.93689868 0.94094985 0.93368355 0.92310773]
# Epoch: 31/50 Iteration: 1660 -> Validation loss: 0.039411 Validation acc: 0.991286 Validation f1-score: [0.99024128 0.99009177 0.99267597 0.99167578]
# Epoch: 31/50 Iteration: 1670 -> Validation loss: 0.034559 Validation acc: 0.990986 Validation f1-score: [0.99279288 0.98918127 0.98958844 0.99166533]
# Epoch: 31/50 Iteration: 1680 -> Train loss: 0.021706 | Train acc: 0.988281 | Train f1-score: [0.93762916 0.94161006 0.93444331 0.92397465]
# Epoch: 31/50 Iteration: 1680 -> Validation loss: 0.037893 Validation acc: 0.989784 Validation f1-score: [0.99072513 0.98912645 0.98682895 0.99181081]
# Epoch: 31/50 Iteration: 1690 -> Validation loss: 0.041279 Validation acc: 0.988882 Validation f1-score: [0.98787473 0.99014646 0.9867511  0.98963672]
# Epoch: 32/50 Iteration: 1700 -> Train loss: 0.027440 | Train acc: 0.988281 | Train f1-score: [0.93833132 0.94224454 0.93515644 0.92482046]
# Epoch: 32/50 Iteration: 1700 -> Validation loss: 0.038292 Validation acc: 0.990385 Validation f1-score: [0.98990852 0.98941772 0.99084515 0.99018498]
# Epoch: 32/50 Iteration: 1710 -> Validation loss: 0.033940 Validation acc: 0.991286 Validation f1-score: [0.99020007 0.99027107 0.99158086 0.99252047]
# Epoch: 32/50 Iteration: 1720 -> Train loss: 0.017129 | Train acc: 0.992188 | Train f1-score: [0.93902073 0.94288307 0.93588265 0.9256586 ]
# Epoch: 32/50 Iteration: 1720 -> Validation loss: 0.040654 Validation acc: 0.988582 Validation f1-score: [0.98926392 0.98451665 0.98858968 0.99168192]
# Epoch: 32/50 Iteration: 1730 -> Validation loss: 0.039145 Validation acc: 0.990084 Validation f1-score: [0.98976091 0.99006131 0.98959639 0.99055271]
# Epoch: 32/50 Iteration: 1740 -> Train loss: 0.011181 | Train acc: 1.000000 | Train f1-score: [0.9396828  0.94348638 0.93658555 0.92646327]
# Epoch: 32/50 Iteration: 1740 -> Validation loss: 0.038720 Validation acc: 0.990084 Validation f1-score: [0.99074288 0.98950723 0.98960724 0.98964705]
# Epoch: 33/50 Iteration: 1750 -> Validation loss: 0.038336 Validation acc: 0.988882 Validation f1-score: [0.98930442 0.98708443 0.98871575 0.98991308]
# Epoch: 33/50 Iteration: 1760 -> Train loss: 0.006798 | Train acc: 1.000000 | Train f1-score: [0.94032475 0.94408837 0.93725784 0.92724363]
# Epoch: 33/50 Iteration: 1760 -> Validation loss: 0.037965 Validation acc: 0.990084 Validation f1-score: [0.99191779 0.98911799 0.98689898 0.99167503]
# Epoch: 33/50 Iteration: 1770 -> Validation loss: 0.056340 Validation acc: 0.984375 Validation f1-score: [0.99042771 0.98424723 0.9747528  0.98799771]
# Epoch: 33/50 Iteration: 1780 -> Train loss: 0.024723 | Train acc: 0.988281 | Train f1-score: [0.94096272 0.94464249 0.93788051 0.92802232]
# Epoch: 33/50 Iteration: 1780 -> Validation loss: 0.055032 Validation acc: 0.984976 Validation f1-score: [0.98697172 0.98064096 0.98525685 0.98654554]
# Epoch: 33/50 Iteration: 1790 -> Validation loss: 0.049517 Validation acc: 0.985877 Validation f1-score: [0.98943676 0.98310757 0.98301049 0.98808604]
# Epoch: 33/50 Iteration: 1800 -> Train loss: 0.068751 | Train acc: 0.980469 | Train f1-score: [0.94158945 0.94518123 0.93850072 0.92872257]
# Epoch: 33/50 Iteration: 1800 -> Validation loss: 0.062423 Validation acc: 0.982272 Validation f1-score: [0.98898423 0.97913919 0.98631967 0.97430694]
# Epoch: 34/50 Iteration: 1810 -> Validation loss: 0.034591 Validation acc: 0.990986 Validation f1-score: [0.99158505 0.98896272 0.98974236 0.99309517]
# Epoch: 34/50 Iteration: 1820 -> Train loss: 0.005734 | Train acc: 1.000000 | Train f1-score: [0.94220576 0.94572199 0.93914649 0.92944506]
# Epoch: 34/50 Iteration: 1820 -> Validation loss: 0.041824 Validation acc: 0.990385 Validation f1-score: [0.99075668 0.99010539 0.99030136 0.98960717]
# Epoch: 34/50 Iteration: 1830 -> Validation loss: 0.048254 Validation acc: 0.987079 Validation f1-score: [0.99097411 0.98672531 0.98463535 0.98513509]
# Epoch: 34/50 Iteration: 1840 -> Train loss: 0.023780 | Train acc: 0.992188 | Train f1-score: [0.94280918 0.94626465 0.93976637 0.93014886]
# Epoch: 34/50 Iteration: 1840 -> Validation loss: 0.036768 Validation acc: 0.989483 Validation f1-score: [0.98902606 0.98917499 0.98962753 0.98930232]
# Epoch: 34/50 Iteration: 1850 -> Validation loss: 0.038765 Validation acc: 0.990385 Validation f1-score: [0.98919281 0.9884466  0.99137658 0.99158752]
# Epoch: 35/50 Iteration: 1860 -> Train loss: 0.015881 | Train acc: 0.996094 | Train f1-score: [0.94338695 0.94679429 0.94038066 0.93085243]
# Epoch: 35/50 Iteration: 1860 -> Validation loss: 0.039550 Validation acc: 0.988882 Validation f1-score: [0.98957681 0.98866053 0.9861555  0.99039348]
# Epoch: 35/50 Iteration: 1870 -> Validation loss: 0.040657 Validation acc: 0.990685 Validation f1-score: [0.99252211 0.98822662 0.99264477 0.98886808]
# Epoch: 35/50 Iteration: 1880 -> Train loss: 0.018874 | Train acc: 0.992188 | Train f1-score: [0.94397022 0.94731609 0.94098455 0.9315462 ]
# Epoch: 35/50 Iteration: 1880 -> Validation loss: 0.042681 Validation acc: 0.989183 Validation f1-score: [0.99049595 0.99084406 0.98575385 0.98912211]
# Epoch: 35/50 Iteration: 1890 -> Validation loss: 0.038497 Validation acc: 0.990385 Validation f1-score: [0.9901484  0.99017788 0.99080882 0.98961695]
# Epoch: 35/50 Iteration: 1900 -> Train loss: 0.007937 | Train acc: 1.000000 | Train f1-score: [0.94453176 0.94783925 0.94158512 0.93221763]
# Epoch: 35/50 Iteration: 1900 -> Validation loss: 0.044749 Validation acc: 0.989183 Validation f1-score: [0.98886133 0.98795676 0.98884275 0.99027314]
# Epoch: 36/50 Iteration: 1910 -> Validation loss: 0.036550 Validation acc: 0.991286 Validation f1-score: [0.99126167 0.9895196  0.99159087 0.99231322]
# Epoch: 36/50 Iteration: 1920 -> Train loss: 0.015725 | Train acc: 0.992188 | Train f1-score: [0.94507558 0.94835628 0.94217013 0.93288593]
# Epoch: 36/50 Iteration: 1920 -> Validation loss: 0.040527 Validation acc: 0.990385 Validation f1-score: [0.99107433 0.99139228 0.9852516  0.99297108]
# Epoch: 36/50 Iteration: 1930 -> Validation loss: 0.037520 Validation acc: 0.991286 Validation f1-score: [0.99135616 0.99012013 0.99159447 0.99150978]
# Epoch: 36/50 Iteration: 1940 -> Train loss: 0.011314 | Train acc: 1.000000 | Train f1-score: [0.94562383 0.94887365 0.94273755 0.93356669]
# Epoch: 36/50 Iteration: 1940 -> Validation loss: 0.038574 Validation acc: 0.989784 Validation f1-score: [0.99069298 0.9891689  0.98892065 0.98994617]
# Epoch: 36/50 Iteration: 1950 -> Validation loss: 0.034331 Validation acc: 0.989183 Validation f1-score: [0.98845406 0.98900398 0.98855733 0.98981947]
# Epoch: 36/50 Iteration: 1960 -> Train loss: 0.004069 | Train acc: 1.000000 | Train f1-score: [0.94615763 0.94937582 0.94328935 0.93422129]
# Epoch: 36/50 Iteration: 1960 -> Validation loss: 0.035134 Validation acc: 0.991887 Validation f1-score: [0.99151903 0.99001666 0.9932842  0.99223317]
# Epoch: 37/50 Iteration: 1970 -> Validation loss: 0.036014 Validation acc: 0.990986 Validation f1-score: [0.99073436 0.98968679 0.98979463 0.99298134]
# Epoch: 37/50 Iteration: 1980 -> Train loss: 0.021612 | Train acc: 0.992188 | Train f1-score: [0.94668998 0.94986094 0.94385526 0.93486744]
# Epoch: 37/50 Iteration: 1980 -> Validation loss: 0.031486 Validation acc: 0.993389 Validation f1-score: [0.99437806 0.99142486 0.99379363 0.99361486]
# Epoch: 37/50 Iteration: 1990 -> Validation loss: 0.033177 Validation acc: 0.993089 Validation f1-score: [0.99378221 0.99151041 0.99269632 0.99410795]
# Epoch: 37/50 Iteration: 2000 -> Train loss: 0.016649 | Train acc: 0.996094 | Train f1-score: [0.94720654 0.95034359 0.94440514 0.93549503]
# Epoch: 37/50 Iteration: 2000 -> Validation loss: 0.032082 Validation acc: 0.991587 Validation f1-score: [0.99017178 0.99138845 0.99161194 0.99243612]
# Epoch: 37/50 Iteration: 2010 -> Validation loss: 0.034268 Validation acc: 0.991587 Validation f1-score: [0.99151058 0.98971356 0.99201175 0.99299472]
# Epoch: 38/50 Iteration: 2020 -> Train loss: 0.010650 | Train acc: 0.996094 | Train f1-score: [0.94770729 0.95080768 0.94492471 0.93610557]
# Epoch: 38/50 Iteration: 2020 -> Validation loss: 0.034466 Validation acc: 0.991587 Validation f1-score: [0.99161885 0.98953219 0.99270559 0.99173157]
# Epoch: 38/50 Iteration: 2030 -> Validation loss: 0.033981 Validation acc: 0.992488 Validation f1-score: [0.99384056 0.99057818 0.99265951 0.9925682 ]
# Epoch: 38/50 Iteration: 2040 -> Train loss: 0.011854 | Train acc: 1.000000 | Train f1-score: [0.94820677 0.95126704 0.94544262 0.93671963]
# Epoch: 38/50 Iteration: 2040 -> Validation loss: 0.035049 Validation acc: 0.990986 Validation f1-score: [0.99131233 0.99021751 0.98928534 0.99236626]
# Epoch: 38/50 Iteration: 2050 -> Validation loss: 0.038163 Validation acc: 0.989784 Validation f1-score: [0.98972822 0.99079062 0.98829288 0.98996633]
# Epoch: 38/50 Iteration: 2060 -> Train loss: 0.007410 | Train acc: 1.000000 | Train f1-score: [0.94870216 0.95171352 0.94594884 0.93732235]
# Epoch: 38/50 Iteration: 2060 -> Validation loss: 0.037321 Validation acc: 0.989183 Validation f1-score: [0.98898968 0.98961991 0.98751368 0.98978786]
# Epoch: 39/50 Iteration: 2070 -> Validation loss: 0.030317 Validation acc: 0.991887 Validation f1-score: [0.99104841 0.99135473 0.99145575 0.99313595]
# Epoch: 39/50 Iteration: 2080 -> Train loss: 0.021237 | Train acc: 0.992188 | Train f1-score: [0.94916164 0.95215436 0.94644996 0.93790102]
# Epoch: 39/50 Iteration: 2080 -> Validation loss: 0.032182 Validation acc: 0.993089 Validation f1-score: [0.99451323 0.98905867 0.99279182 0.99552763]
# Epoch: 39/50 Iteration: 2090 -> Validation loss: 0.034865 Validation acc: 0.991286 Validation f1-score: [0.99339834 0.99008231 0.99022428 0.99060549]
# Epoch: 39/50 Iteration: 2100 -> Train loss: 0.010645 | Train acc: 1.000000 | Train f1-score: [0.94963038 0.95258699 0.94694888 0.93847467]
# Epoch: 39/50 Iteration: 2100 -> Validation loss: 0.039912 Validation acc: 0.990385 Validation f1-score: [0.9891925  0.99065559 0.98949758 0.99176395]
# Epoch: 39/50 Iteration: 2110 -> Validation loss: 0.034430 Validation acc: 0.990986 Validation f1-score: [0.99018267 0.99211295 0.98983097 0.99122466]
# Epoch: 39/50 Iteration: 2120 -> Train loss: 0.007146 | Train acc: 1.000000 | Train f1-score: [0.95008697 0.95301536 0.94743885 0.93902957]
# Epoch: 39/50 Iteration: 2120 -> Validation loss: 0.037429 Validation acc: 0.990084 Validation f1-score: [0.98870314 0.9901507  0.99220355 0.98894347]
# Epoch: 40/50 Iteration: 2130 -> Validation loss: 0.036100 Validation acc: 0.991887 Validation f1-score: [0.99217207 0.99079518 0.99269632 0.99109584]
# Epoch: 40/50 Iteration: 2140 -> Train loss: 0.008361 | Train acc: 1.000000 | Train f1-score: [0.95052473 0.9534282  0.94790048 0.93958069]
# Epoch: 40/50 Iteration: 2140 -> Validation loss: 0.039316 Validation acc: 0.991286 Validation f1-score: [0.99241296 0.9890751  0.98834572 0.99495348]
# Epoch: 40/50 Iteration: 2150 -> Validation loss: 0.030164 Validation acc: 0.992788 Validation f1-score: [0.99305061 0.99079327 0.99310547 0.99373248]
# Epoch: 40/50 Iteration: 2160 -> Train loss: 0.020664 | Train acc: 0.996094 | Train f1-score: [0.95097125 0.95384493 0.94836435 0.940133  ]
# Epoch: 40/50 Iteration: 2160 -> Validation loss: 0.035088 Validation acc: 0.991587 Validation f1-score: [0.99191101 0.99127744 0.99110126 0.99198114]
# Epoch: 40/50 Iteration: 2170 -> Validation loss: 0.030336 Validation acc: 0.991887 Validation f1-score: [0.99183258 0.99020691 0.99264498 0.9925208 ]
# Epoch: 41/50 Iteration: 2180 -> Train loss: 0.011552 | Train acc: 0.996094 | Train f1-score: [0.95139049 0.95424431 0.94881974 0.94063465]
# Epoch: 41/50 Iteration: 2180 -> Validation loss: 0.040277 Validation acc: 0.990685 Validation f1-score: [0.99132636 0.99135029 0.99039208 0.98897153]
# Epoch: 41/50 Iteration: 2190 -> Validation loss: 0.041158 Validation acc: 0.990986 Validation f1-score: [0.99308652 0.98711197 0.99282304 0.99065611]
# Epoch: 41/50 Iteration: 2200 -> Train loss: 0.008502 | Train acc: 1.000000 | Train f1-score: [0.95182025 0.95464058 0.94927801 0.94114883]
# Epoch: 41/50 Iteration: 2200 -> Validation loss: 0.029430 Validation acc: 0.992788 Validation f1-score: [0.99339834 0.99137538 0.99191571 0.99356002]
# Epoch: 41/50 Iteration: 2210 -> Validation loss: 0.035010 Validation acc: 0.991587 Validation f1-score: [0.99184159 0.99020646 0.99071009 0.99307233]
# Epoch: 41/50 Iteration: 2220 -> Train loss: 0.032790 | Train acc: 0.992188 | Train f1-score: [0.95224356 0.95501714 0.94971051 0.94164829]
# Epoch: 41/50 Iteration: 2220 -> Validation loss: 0.046267 Validation acc: 0.989183 Validation f1-score: [0.99099921 0.98792791 0.98974761 0.98735156]
# Epoch: 42/50 Iteration: 2230 -> Validation loss: 0.038402 Validation acc: 0.989784 Validation f1-score: [0.99186658 0.98744751 0.98888357 0.99049157]
# Epoch: 42/50 Iteration: 2240 -> Train loss: 0.010324 | Train acc: 1.000000 | Train f1-score: [0.9526486  0.95537872 0.95013136 0.94214816]
# Epoch: 42/50 Iteration: 2240 -> Validation loss: 0.032339 Validation acc: 0.992488 Validation f1-score: [0.99281114 0.99026106 0.99329109 0.99318131]
# Epoch: 42/50 Iteration: 2250 -> Validation loss: 0.035153 Validation acc: 0.991587 Validation f1-score: [0.99180903 0.99123386 0.99210913 0.99036337]
# Epoch: 42/50 Iteration: 2260 -> Train loss: 0.004888 | Train acc: 1.000000 | Train f1-score: [0.9530395  0.95577074 0.95056231 0.94264305]
# Epoch: 42/50 Iteration: 2260 -> Validation loss: 0.041586 Validation acc: 0.989784 Validation f1-score: [0.98733681 0.99126151 0.98874597 0.99101113]
# Epoch: 42/50 Iteration: 2270 -> Validation loss: 0.034104 Validation acc: 0.990385 Validation f1-score: [0.98957721 0.99027179 0.99021952 0.99054957]
# Epoch: 43/50 Iteration: 2280 -> Train loss: 0.014771 | Train acc: 0.992188 | Train f1-score: [0.95344205 0.95614129 0.95098319 0.94313155]
# Epoch: 43/50 Iteration: 2280 -> Validation loss: 0.035793 Validation acc: 0.990986 Validation f1-score: [0.9901818  0.98939101 0.99283221 0.99126637]
# Epoch: 43/50 Iteration: 2290 -> Validation loss: 0.031851 Validation acc: 0.992488 Validation f1-score: [0.99312568 0.99197154 0.99088695 0.99298141]
# Epoch: 43/50 Iteration: 2300 -> Train loss: 0.009380 | Train acc: 0.996094 | Train f1-score: [0.9538433  0.95651157 0.95139618 0.94361109]
# Epoch: 43/50 Iteration: 2300 -> Validation loss: 0.036158 Validation acc: 0.992188 Validation f1-score: [0.99262589 0.99059469 0.99145319 0.99379669]
# Epoch: 43/50 Iteration: 2310 -> Validation loss: 0.029915 Validation acc: 0.992488 Validation f1-score: [0.99166352 0.99154314 0.99327109 0.99297084]
# Epoch: 43/50 Iteration: 2320 -> Train loss: 0.006487 | Train acc: 1.000000 | Train f1-score: [0.95422641 0.95688333 0.95181204 0.94408487]
# Epoch: 43/50 Iteration: 2320 -> Validation loss: 0.037111 Validation acc: 0.989784 Validation f1-score: [0.9896377  0.98911799 0.98813898 0.99164586]
# Epoch: 43/50 Iteration: 2330 -> Validation loss: 0.035037 Validation acc: 0.991587 Validation f1-score: [0.99212257 0.99001893 0.99156796 0.99229034]
# Epoch: 44/50 Iteration: 2340 -> Train loss: 0.011259 | Train acc: 1.000000 | Train f1-score: [0.95459788 0.95722799 0.95219453 0.94454264]
# Epoch: 44/50 Iteration: 2340 -> Validation loss: 0.040156 Validation acc: 0.990084 Validation f1-score: [0.99103226 0.98689464 0.98893011 0.99303644]
# Epoch: 44/50 Iteration: 2350 -> Validation loss: 0.056265 Validation acc: 0.986478 Validation f1-score: [0.9910004  0.98627733 0.98052782 0.98693447]
# Epoch: 44/50 Iteration: 2360 -> Train loss: 0.006603 | Train acc: 1.000000 | Train f1-score: [0.95496104 0.95756448 0.95256414 0.94498325]
# Epoch: 44/50 Iteration: 2360 -> Validation loss: 0.052339 Validation acc: 0.989183 Validation f1-score: [0.99215908 0.98622846 0.98638777 0.99140396]
# Epoch: 44/50 Iteration: 2370 -> Validation loss: 0.030668 Validation acc: 0.992488 Validation f1-score: [0.99243665 0.9902266  0.99201897 0.99481731]
# Epoch: 44/50 Iteration: 2380 -> Train loss: 0.013096 | Train acc: 0.996094 | Train f1-score: [0.95533645 0.9578837  0.95292612 0.94541843]
# Epoch: 44/50 Iteration: 2380 -> Validation loss: 0.035944 Validation acc: 0.988281 Validation f1-score: [0.99013811 0.98866053 0.98436682 0.98935557]
# Epoch: 45/50 Iteration: 2390 -> Validation loss: 0.034267 Validation acc: 0.992788 Validation f1-score: [0.99208895 0.99133584 0.99453221 0.99284856]
# Epoch: 45/50 Iteration: 2400 -> Train loss: 0.004027 | Train acc: 1.000000 | Train f1-score: [0.95569893 0.95821632 0.95330887 0.9458599 ]
# Epoch: 45/50 Iteration: 2400 -> Validation loss: 0.028486 Validation acc: 0.993389 Validation f1-score: [0.99360209 0.99126072 0.99392037 0.99434786]
# Epoch: 45/50 Iteration: 2410 -> Validation loss: 0.032073 Validation acc: 0.991587 Validation f1-score: [0.99218015 0.98956917 0.99208404 0.99173157]
# Epoch: 45/50 Iteration: 2420 -> Train loss: 0.010718 | Train acc: 0.996094 | Train f1-score: [0.95604682 0.95854963 0.9536821  0.94629778]
# Epoch: 45/50 Iteration: 2420 -> Validation loss: 0.028296 Validation acc: 0.992788 Validation f1-score: [0.99279481 0.99088097 0.99329524 0.99376087]
# Epoch: 45/50 Iteration: 2430 -> Validation loss: 0.032754 Validation acc: 0.992188 Validation f1-score: [0.99273355 0.99088871 0.99270609 0.99173157]
# Epoch: 46/50 Iteration: 2440 -> Train loss: 0.012201 | Train acc: 0.996094 | Train f1-score: [0.95640082 0.95887071 0.95405195 0.94673468]
# Epoch: 46/50 Iteration: 2440 -> Validation loss: 0.039293 Validation acc: 0.989784 Validation f1-score: [0.99124569 0.9855429  0.99085302 0.99128452]
# Epoch: 46/50 Iteration: 2450 -> Validation loss: 0.039481 Validation acc: 0.989483 Validation f1-score: [0.98908338 0.99079518 0.98918026 0.98787659]
# Epoch: 46/50 Iteration: 2460 -> Train loss: 0.005380 | Train acc: 1.000000 | Train f1-score: [0.95672812 0.95918443 0.95440347 0.94714588]
# Epoch: 46/50 Iteration: 2460 -> Validation loss: 0.030666 Validation acc: 0.992788 Validation f1-score: [0.99280306 0.99094684 0.99268604 0.99436649]
# Epoch: 46/50 Iteration: 2470 -> Validation loss: 0.034911 Validation acc: 0.990986 Validation f1-score: [0.99160375 0.9890751  0.98826571 0.99434786]
# Epoch: 46/50 Iteration: 2480 -> Train loss: 0.013333 | Train acc: 0.996094 | Train f1-score: [0.95707709 0.95949912 0.95475491 0.9475663 ]
# Epoch: 46/50 Iteration: 2480 -> Validation loss: 0.028913 Validation acc: 0.991887 Validation f1-score: [0.99224972 0.99075633 0.99088717 0.99301296]
# Epoch: 46/50 Iteration: 2490 -> Validation loss: 0.033838 Validation acc: 0.991286 Validation f1-score: [0.99331497 0.98884804 0.99134573 0.99130208]
# Epoch: 47/50 Iteration: 2500 -> Train loss: 0.004250 | Train acc: 1.000000 | Train f1-score: [0.95741444 0.95979713 0.95509477 0.94796678]
# Epoch: 47/50 Iteration: 2500 -> Validation loss: 0.037925 Validation acc: 0.989784 Validation f1-score: [0.99022304 0.99154314 0.98740995 0.98934515]
# Epoch: 47/50 Iteration: 2510 -> Validation loss: 0.031822 Validation acc: 0.993089 Validation f1-score: [0.99381502 0.99116472 0.9937936  0.993191  ]
# Epoch: 47/50 Iteration: 2520 -> Train loss: 0.007430 | Train acc: 1.000000 | Train f1-score: [0.95774005 0.96010436 0.9554485  0.94837641]
# Epoch: 47/50 Iteration: 2520 -> Validation loss: 0.026595 Validation acc: 0.992188 Validation f1-score: [0.991977   0.99143512 0.99028771 0.99418502]
# Epoch: 47/50 Iteration: 2530 -> Validation loss: 0.028231 Validation acc: 0.993690 Validation f1-score: [0.99495643 0.9919111  0.99329109 0.99433809]
# Epoch: 47/50 Iteration: 2540 -> Train loss: 0.005733 | Train acc: 1.000000 | Train f1-score: [0.95806621 0.96040587 0.95578804 0.94877699]
# Epoch: 47/50 Iteration: 2540 -> Validation loss: 0.031044 Validation acc: 0.991286 Validation f1-score: [0.99022323 0.99153513 0.99098839 0.99157747]
# Epoch: 48/50 Iteration: 2550 -> Validation loss: 0.028104 Validation acc: 0.993990 Validation f1-score: [0.99360215 0.99361935 0.99335773 0.9949244 ]
# Epoch: 48/50 Iteration: 2560 -> Train loss: 0.005795 | Train acc: 1.000000 | Train f1-score: [0.95839382 0.96070364 0.95612435 0.94917424]
# Epoch: 48/50 Iteration: 2560 -> Validation loss: 0.029606 Validation acc: 0.992488 Validation f1-score: [0.99312568 0.99098172 0.99158447 0.9934724 ]
# Epoch: 48/50 Iteration: 2570 -> Validation loss: 0.032671 Validation acc: 0.992488 Validation f1-score: [0.99393486 0.99088871 0.99207036 0.99235626]
# Epoch: 48/50 Iteration: 2580 -> Train loss: 0.008292 | Train acc: 0.996094 | Train f1-score: [0.95871309 0.96100331 0.95645513 0.9495559 ]
# Epoch: 48/50 Iteration: 2580 -> Validation loss: 0.030244 Validation acc: 0.992488 Validation f1-score: [0.99433896 0.9902708  0.991415   0.99379669]
# Epoch: 48/50 Iteration: 2590 -> Validation loss: 0.032642 Validation acc: 0.991286 Validation f1-score: [0.9913987  0.99088871 0.99035266 0.99175065]
# Epoch: 49/50 Iteration: 2600 -> Train loss: 0.007959 | Train acc: 1.000000 | Train f1-score: [0.95902803 0.9612945  0.95677781 0.94993177]
# Epoch: 49/50 Iteration: 2600 -> Validation loss: 0.034335 Validation acc: 0.991887 Validation f1-score: [0.99440204 0.98894003 0.99074004 0.99316412]
# Epoch: 49/50 Iteration: 2610 -> Validation loss: 0.030021 Validation acc: 0.991587 Validation f1-score: [0.991977   0.99085267 0.99028771 0.99236596]
# Epoch: 49/50 Iteration: 2620 -> Train loss: 0.003656 | Train acc: 1.000000 | Train f1-score: [0.95933143 0.96158095 0.95709926 0.95030523]
# Epoch: 49/50 Iteration: 2620 -> Validation loss: 0.029677 Validation acc: 0.993690 Validation f1-score: [0.99498352 0.99206853 0.99329087 0.99421124]
# Epoch: 49/50 Iteration: 2630 -> Validation loss: 0.028597 Validation acc: 0.993089 Validation f1-score: [0.99420761 0.99147245 0.99206035 0.9942345 ]
# Epoch: 49/50 Iteration: 2640 -> Train loss: 0.006022 | Train acc: 1.000000 | Train f1-score: [0.95963952 0.96186714 0.95741781 0.9506817 ]
# Epoch: 49/50 Iteration: 2640 -> Validation loss: 0.028111 Validation acc: 0.993089 Validation f1-score: [0.99497469 0.99028389 0.99197066 0.99495348]
# Epoch: 49/50 Iteration: 2650 -> Validation loss: 0.032291 Validation acc: 0.990084 Validation f1-score: [0.98779495 0.99090149 0.99092097 0.9901726 ]
# [[3320    1    1    2]
#  [   0 3515    2    1]
#  [   0    1 3382    1]
#  [   3    0    0 3339]]
#  Level:0  Accuracy:0.9991   Precision:0.9991                 Recall:0.9988   F1-Score:0.9989
#  Level:1  Accuracy:0.9991   Precision:0.9994                 Recall:0.9991   F1-Score:0.9993
#  Level:2  Accuracy:0.9991   Precision:0.9991                 Recall:0.9994   F1-Score:0.9993
#  Level:3  Accuracy:0.9991   Precision:0.9988                 Recall:0.9991   F1-Score:0.9990

# %%
train_writer.add_graph(sess.graph)
train_writer.flush()
tbc.close()

# %% [markdown]
# ## Plot the Recall Metrics for training and validation sets

# %%
df_rec = pd.DataFrame(validation_recall).rename(columns={0: 'Normal Group (0)', 1: 'Minor Group (1)', 2: 'Moderate Group (2)', 3: 'Severe Group (3)'})

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(16, 10))
plt.subplots_adjust(wspace=0.15, hspace=0.3);

axe_pos = [axes[0][0], axes[0][1], axes[1][0], axes[1][1]]
df_rec.plot(subplots=True, ax=axe_pos, legend=True, sharex=False, sharey=False, linewidth=1.2)

[a.legend(fontsize=12, loc='lower right') for a in axe_pos]
[a.set_xlabel('Iteration') for a in axe_pos]
[a.set_ylabel('Recall') for a in axe_pos]

fig.savefig('drive/My Drive/DL/' + channel_name + '/validation_recall_12_01.png', dpi=fig.dpi)

# %%
df_rec = pd.DataFrame(train_recall).rename(columns={0: 'Normal Group (0)', 1: 'Minor Group (1)', 2: 'Moderate Group (2)', 3: 'Severe Group (3)'})

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(16, 10))
plt.subplots_adjust(wspace=0.15, hspace=0.3);

axe_pos = [axes[0][0], axes[0][1], axes[1][0], axes[1][1]]
df_rec.plot(subplots=True, ax=axe_pos, legend=True, sharex=False, sharey=False, linewidth=1.2)

[a.legend(fontsize=12, loc='lower right') for a in axe_pos]
[a.set_xlabel('Iteration') for a in axe_pos]
[a.set_ylabel('Recall') for a in axe_pos]

fig.savefig('drive/My Drive/DL/' + channel_name + '/train_recall_12_01.png', dpi=fig.dpi)

# %%
# Plot training and test loss  
t = np.arange(iteration-1)

fig = plt.figure(figsize = (18,8))
plt.plot(t, np.array(train_loss), 'r-', t[t % 10 == 0], np.array(validation_loss), 'b-o', linewidth=1, markersize=3)
fig.suptitle('ECG Loss', fontsize=25)
plt.xlabel('Iteration', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.legend(['train', 'validation'], loc='upper right', prop={'size': 18})
plt.show()


fig.savefig('drive/My Drive/DL/' + channel_name + '/loss_05_12.png', dpi=fig.dpi, transparent=True)

# %%
# Plot Accuracies
fig = plt.figure(figsize = (18,10))

plt.plot(t, np.array(train_acc), 'r-', t[t % 10 == 0], validation_acc, 'b-o', linewidth=1, markersize=3)
fig.suptitle('ECG Accuracy', fontsize=25)
plt.xlabel("Iteration", fontsize=20)
plt.ylabel("Accuray", fontsize=20)
plt.legend(['train', 'validation'], loc='upper left', prop={'size': 15})
plt.show()
fig.savefig('drive/My Drive/DL/' + channel_name + '/acc_05_12.png', dpi=fig.dpi, transparent=True)

# %% [markdown]
# # Test the CNN model with test set

# %%
test_acc = []
test_confusion_matrix = np.zeros((4,4))

with tf.Session(graph=graph) as sess:
  # Restore
  saver.restore(sess, tf.train.latest_checkpoint('drive/My Drive/DL/ECG'))
  
  for x_t, y_t in get_batches(X_test, y_test, batch_size):
    feed = {inputs_: x_t,
            labels_: y_t,
            keep_prob_: 1.0}
    
    batch_acc, y_pred_batch = sess.run([accuracy, y_p], feed_dict=feed)
    test_acc.append(batch_acc)
    test_confusion_matrix = test_confusion_matrix + sk.metrics.confusion_matrix(np.argmax(y_t, 1), y_pred_batch)
    
  print('Test accuracy: {:.6f}'.format(np.mean(test_acc)))
  print(test_confusion_matrix.astype(int))
# Out:
# INFO:tensorflow:Restoring parameters from drive/My Drive/DL/ECG/ccsh.ckpt
# Test accuracy: 0.989746
# [[1000    0    3    5]
#  [  10 1032    6    8]
#  [   1    0 1022    3]
#  [   3    1    2 1000]]

# %%
for label in range(4):
    print(f' Level:{label}  Accuracy:{accuracy_train(test_confusion_matrix):.4f}    Precision:{precision(label, test_confusion_matrix):.4f} \
    Recall:{recall(label, test_confusion_matrix):.4f}    F1-Score:{f1_score(label, test_confusion_matrix):.4f}')
# Out:
#  Level:0  Accuracy:0.9897    Precision:0.9862     Recall:0.9921    F1-Score:0.9891
#  Level:1  Accuracy:0.9897    Precision:0.9990     Recall:0.9773    F1-Score:0.9880
#  Level:2  Accuracy:0.9897    Precision:0.9894     Recall:0.9961    F1-Score:0.9927
#  Level:3  Accuracy:0.9897    Precision:0.9843     Recall:0.9940    F1-Score:0.9891
